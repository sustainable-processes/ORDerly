# %% [markdown]
# # Inspect extracted data

# %%
import pandas as pd

# %%
path = "/Users/dsw46/Projects_local/test_orderly_model/ORDerly/data/orderly/uspto_with_trust/unfiltered/unfiltered_orderly_ord.parquet"
df = pd.read_parquet(path)

# %%
for i in df['catalyst_003']:
    if i != "<missing>":
        print(i)
# Out:
# [Cl-]

# %%
cat_cols = ['cat1', 'cat2']
number_of_columns_to_keep = 1
cat_cols[number_of_columns_to_keep:]
# Out:
# ['cat2']

# %% [markdown]
# ## Trying to canonicalise

# %%
from rdkit import Chem
def canon(smi):
    try:
        return Chem.MolToSmiles(Chem.MolFromSmiles(smi))
    except:
        return None

# %%
canon("[BH3]")
# Out:
# 'B'
