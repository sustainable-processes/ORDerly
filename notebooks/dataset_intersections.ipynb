# %% [markdown]
# # Find the rows in test set that are also in train

# %%
import pandas as pd

# %%
path = '/Users/dsw46/Projects_local/orderly_27_05/ORDerly/data/orderly/uspto_no_trust/filtered/filtered_orderly_ord.parquet'
df = pd.read_parquet(path)

# %%
solv = df[['solvent_000', 'solvent_001']]
#iterate over all rows
for index, row in solv.iterrows():
    if 'OCC1CCCO1' in row.values:
        print(index)
        print(row.values)
        break
# Out:
# 34307
# ['OCC1CCCO1' None]

# %%
train_idx = range(int(len(df)*0.8))
test_idx = range(int(len(df)*0.8), len(df))
train_df = df.iloc[train_idx]
test_df = df.iloc[test_idx]

# %%
def get_intersection(df1, df2):
    return df1.index.intersection(df2.index)
# Out:
#                           agent_000               agent_001 agent_002
# 545293                O=C([O-])[O-]                   [Cs+]      None  \
# 545294                         BrBr                    [K+]      None
# 545295                O=C([O-])[O-]                    [K+]      None
# 545296  CN1CCC(C(=O)c2cccc(N)n2)CC1  O=C(Cl)c1c(F)cc(F)cc1F      None
# 545297                           Cl                    None      None
# ...                             ...                     ...       ...
# 681612                        C[O-]                   [Na+]      None
# 681613      C(=NC1CCCCC1)=NC1CCCCC1           CN(C)c1ccncc1      None
# 681614                         [Pd]                    None      None
# 681615                   O=C([O-])O                   [Na+]      None
# 681616                        [Cu]I            CNC1CCCCC1NC     [Na+]
#
#        date_of_experiment                           extracted_from_file
# 545293                NaT  ord_dataset-f8e6e6a2d2bf4135b9e346456c81700f  \
# 545294                NaT  ord_dataset-f8e6e6a2d2bf4135b9e346456c81700f
# 545295                NaT  ord_dataset-f8e6e6a2d2bf4135b9e346456c81700f
# 545296                NaT  ord_dataset-f8e6e6a2d2bf4135b9e346456c81700f
# 545297                NaT  ord_dataset-f8e6e6a2d2bf4135b9e346456c81700f
# ...                   ...                                           ...
# 681612                NaT  ord_dataset-0b32b90cc77b4a3db47ad263e0bbc1a8
# 681613                NaT  ord_dataset-0b32b90cc77b4a3db47ad263e0bbc1a8
# 681614                NaT  ord_dataset-0b32b90cc77b4a3db47ad263e0bbc1a8
# 681615                NaT  ord_dataset-0b32b90cc77b4a3db47ad263e0bbc1a8
# 681616                NaT  ord_dataset-0b32b90cc77b4a3db47ad263e0bbc1a8
#
#                 grant_date  is_mapped
# 545293 2014-01-01 00:04:00       True  \
# 545294 2014-01-01 00:04:00       True
# 545295 2014-01-01 00:04:00       True
# 545296 2014-01-01 00:04:00       True
# 545297 2014-01-01 00:04:00       True
# ...                    ...        ...
# 681612 2016-01-01 00:09:00       True
# 681613 2016-01-01 00:09:00       True
# 681614 2016-01-01 00:09:00       True
# 681615 2016-01-01 00:09:00       True
# 681616 2016-01-01 00:09:00       True
#
#                                         procedure_details
# 545293  To a solution of benzyl (3-hydroxy-4-methylphe...  \
# 545294  To a solution of potassium thiocyanate (62.9 g...
# 545295  To a solution of benzyl {3-[(2-amino[1,3]thiaz...
# 545296  The present invention is directed to a process...
# 545297  To a suspension of {(cis)-1-acetyl-2-methyl-6-...
# ...                                                   ...
# 681612  10.0 g of p-acetoxystyrene was dissolved in 40...
# 681613  4-(benzyloxy)benzoic acid (20.0 g, 87.6 mmol),...
# 681614  The 4-(hexyloxy)phenyl 4-(benzyloxy)benzoate o...
# 681615  A 500 ml round bottom flask was charged with N...
# 681616  A 100 ml three neck round bottom flask was cha...
#
#                                               product_000
# 545293  Cc1ccc(NC(=O)OCc2ccccc2)cc1Oc1ccc([N+](=O)[O-]...  \
# 545294       Cc1ccc(NC(=O)OCc2ccccc2)cc1Oc1ccc2nc(N)sc2n1
# 545295  Cc1ccc(NC(=O)OCc2ccccc2)cc1Oc1ccc2nc(NC(=O)C3C...
# 545296    CN1CCC(C(=O)C2CCCC(NC(=O)c3c(F)cc(F)cc3F)N2)CC1
# 545297  CC(=O)N1c2ccc(-c3ccc(CN4CCCCC4)cc3)cc2[C@H](N)...
# ...                                                   ...
# 681612                                     C=Cc1ccc(O)cc1
# 681613        CCCCCCOc1ccc(OC(=O)c2ccc(OCc3ccccc3)cc2)cc1
# 681614                 CCCCCCOc1ccc(OC(=O)c2ccc(O)cc2)cc1
# 681615      COc1cccc(-c2nccn2-c2c(C(C)C)cc(Br)cc2C(C)C)c1
# 681616                    Ic1ccc2c3ccccc3n(-c3ccccn3)c2c1
#
#                                              reactant_000
# 545293                       Cc1ccc(NC(=O)OCc2ccccc2)cc1O  \
# 545294            Cc1ccc(NC(=O)OCc2ccccc2)cc1Oc1ccc(N)cn1
# 545295       Cc1ccc(NC(=O)OCc2ccccc2)cc1Oc1ccc2nc(N)sc2n1
# 545296    CN1CCC(C(=O)c2cccc(NC(=O)c3c(F)cc(F)cc3F)n2)CC1
# 545297  CC(=O)N1c2ccc(-c3ccc(CN4CCCCC4)cc3)cc2[C@H](NC...
# ...                                                   ...
# 681612                               C=Cc1ccc(OC(C)=O)cc1
# 681613                                 CCCCCCOc1ccc(O)cc1
# 681614        CCCCCCOc1ccc(OC(=O)c2ccc(OCc3ccccc3)cc2)cc1
# 681615         COc1cccc(C(=N)Nc2c(C(C)C)cc(Br)cc2C(C)C)c1
# 681616                   Brc1ccc2c3ccccc3n(-c3ccccn3)c2c1
#
#                       reactant_001
# 545293    O=[N+]([O-])c1ccc(Cl)nc1  \
# 545294                     N#C[S-]
# 545295                O=C(Cl)C1CC1
# 545296                        None
# 545297                        None
# ...                            ...
# 681612                        None
# 681613  O=C(O)c1ccc(OCc2ccccc2)cc1
# 681614                        None
# 681615                      O=CCCl
# 681616                        [I-]
#
#                                                   rxn_str  rxn_time
# 545293  [OH:1][C:2]1[CH:3]=[C:4]([NH:9][C:10](=[O:19])...       4.0  \
# 545294  [S-:1][C:2]#[N:3].[K+].[NH2:5][C:6]1[CH:7]=[CH...      18.0
# 545295  [NH2:1][C:2]1[S:3][C:4]2[C:9]([N:10]=1)=[CH:8]...       0.5
# 545296  [F:1][C:2]1[CH:25]=[C:24]([F:26])[CH:23]=[C:22...       NaN
# 545297  [C:1]([N:4]1[C:13]2[C:8](=[CH:9][C:10]([C:14]3...       NaN
# ...                                                   ...       ...
# 681612  C([O:4][C:5]1[CH:12]=[CH:11][C:8]([CH:9]=[CH2:...       5.0
# 681613  [CH2:1]([O:8][C:9]1[CH:17]=[CH:16][C:12]([C:13...       3.0
# 681614  C([O:8][C:9]1[CH:30]=[CH:29][C:12]([C:13]([O:1...       NaN
# 681615  [Br:1][C:2]1[CH:7]=[C:6]([CH:8]([CH3:10])[CH3:...       NaN
# 681616  Br[C:2]1[CH:14]=[CH:13][C:12]2[C:11]3[C:6](=[C...       NaN
#
#        solvent_000 solvent_001  temperature  yield_000
# 545293   CCOC(C)=O    CN(C)C=O         25.0       75.4
# 545294     CC(=O)O        None         25.0       73.5
# 545295          CO    c1ccncc1         25.0       81.4
# 545296  Clc1ccccc1        None          NaN        NaN
# 545297          CO        None          NaN       70.0
# ...            ...         ...          ...        ...
# 681612   CCOC(C)=O          CO          0.0      178.2
# 681613       ClCCl           O         25.0       70.3
# 681614  C1=CCC=CC1     C1CCOC1         60.0        NaN
# 681615      CC(C)O           O          NaN       78.6
# 681616    C1COCCO1           O          NaN       83.1
#
# [136324 rows x 17 columns]

# %% [markdown]
# # Find reactions in test set (rare-> other) that don't appear in train set

# %%
import pandas as pd

# %%
test_df_path = "/Users/dsw46/Library/CloudStorage/OneDrive-UniversityofCambridge/Datasets/orderly_v5/orderly_no_trust_no_map_test.parquet"
train_df_path = "/Users/dsw46/Library/CloudStorage/OneDrive-UniversityofCambridge/Datasets/orderly_v5/orderly_no_trust_with_map_train.parquet"
test_df = pd.read_parquet(test_df_path)
train_df = pd.read_parquet(train_df_path)

# %%
# Extract the values from the "rxn_str" column in train_df
train_rxn_str_values = train_df["rxn_str"].values

# Filter test_df based on values present in train_rxn_str_values
intersection_indices = test_df[test_df["rxn_str"].isin(train_rxn_str_values)].index

# Print the filtered rows
print(len(intersection_indices))
print(len(test_df))
# Out:
# 30422
# 33930

# %%
test_df = test_df.drop(intersection_indices)
len(test_df)
# Out:
# 3508

# %%
#save the new test_df as parquet
test_df.to_parquet("/Users/dsw46/Library/CloudStorage/OneDrive-UniversityofCambridge/Datasets/intersection_test_set.parquet")

# %% [markdown]
# # Find reactions/rows shared between the test sets

# %%
import pandas as pd

# %%
no_trust_test_path = "/Users/dsw46/Library/CloudStorage/OneDrive-UniversityofCambridge/Datasets/orderly_v5/orderly_no_trust_no_map_test.parquet"
with_trust_test_path = "/Users/dsw46/Library/CloudStorage/OneDrive-UniversityofCambridge/Datasets/orderly_v5/orderly_with_trust_no_map_test.parquet"
df1 = pd.read_parquet(no_trust_test_path)
df2 = pd.read_parquet(with_trust_test_path)

# %%
# Find indices where the rxn_str is the same

# Extract the values from the "rxn_str" column in df1 and df2
rxn_str_2 = df2["rxn_str"].values

# Filter df1 based on values present in df2 and vice versa
intersection_indices1 = df1[df1["rxn_str"].isin(rxn_str_2)].index

# Print the filtered rows
print(len(intersection_indices1))
print(len(df1))
print(len(df2))

corresponding_indices_in_df2 = []

# Loop through the filtered indices in df1
for idx in intersection_indices1:
    # Extract the 'rxn_str' value from df1
    rxn_str_value = df1.loc[idx, 'rxn_str']
    
    # Find the index in df2 where 'rxn_str' equals rxn_str_value
    corresponding_indices_in_df2.append(df2[df2['rxn_str'] == rxn_str_value].index[0])
# Out:
# 275
# 33930
# 3373

# %%
intersection_indices1
# Out:
# Int64Index([ 71626, 154117, 149010,  60387,  64932, 119752,  25055, 227446,
#             352683,   3653,
#             ...
#              19436,  91628,  12699,  12990, 206402,  79597, 235712,  70583,
#             300095, 241611],
#            dtype='int64', length=275)

# %%
corresponding_indices_in_df2[:5]
# Out:
# [6663, 15277, 14743, 5554, 6018]

# %%
df1.loc[intersection_indices1[0]]
# Out:
# agent_000                                                             Cl
# agent_001                                                           [Zn]
# agent_002                                                           None
# date_of_experiment                                                   NaT
# extracted_from_file         ord_dataset-127eb5fdd5b4402e92b51d0b55a5dcb5
# grant_date                                           1997-01-01 00:01:00
# is_mapped                                                           True
# procedure_details      To a suspension of 1.52 g of trans-1,2,3,4-tet...
# product_000                 COc1cc2c(cc1OC)[C@@H](c1ccc(C)s1)[C@H](N)CC2
# reactant_000           COc1cc2c(cc1OC)[C@@H](c1ccc(C)s1)[C@H]([N+](=O...
# reactant_001                                                        NULL
# rxn_str                [CH3:1][O:2][C:3]1[CH:4]=[C:5]2[C:10](=[CH:11]...
# rxn_time                                                             0.5
# solvent_000                                                          CCO
# solvent_001                                                         None
# temperature                                                         25.0
# yield_000                                                           98.9
# Name: 71626, dtype: object

# %%
df2.loc[corresponding_indices_in_df2[0]]
# Out:
# catalyst_000                                                        [Zn]
# date_of_experiment                                                   NaT
# extracted_from_file         ord_dataset-127eb5fdd5b4402e92b51d0b55a5dcb5
# grant_date                                           1997-01-01 00:01:00
# is_mapped                                                           True
# procedure_details      To a suspension of 1.52 g of trans-1,2,3,4-tet...
# product_000                 COc1cc2c(cc1OC)[C@@H](c1ccc(C)s1)[C@H](N)CC2
# reactant_000           COc1cc2c(cc1OC)[C@@H](c1ccc(C)s1)[C@H]([N+](=O...
# reactant_001                                                          Cl
# reagent_000                                                         None
# reagent_001                                                         None
# rxn_str                [CH3:1][O:2][C:3]1[CH:4]=[C:5]2[C:10](=[CH:11]...
# rxn_time                                                             0.5
# solvent_000                                                          CCO
# solvent_001                                                         None
# temperature                                                         25.0
# yield_000                                                           98.9
# Name: 6663, dtype: object
