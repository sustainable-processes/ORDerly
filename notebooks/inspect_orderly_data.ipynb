# %% [markdown]
# # Inspect ORD file

# %%
import ord_schema
from ord_schema import message_helpers, validations
from ord_schema.proto import dataset_pb2
import os
import fnmatch

# %%
# Inspect raw ORD file
# Find the schema here
# https://github.com/open-reaction-database/ord-schema/blob/main/ord_schema/proto/reaction.proto


# Load Dataset message
pb = "../data/ord/02/ord_dataset-02ee2261663048188cf6d85d2cc96e3f.pb.gz"
data = message_helpers.load_message(pb, dataset_pb2.Dataset)

# Inspect a reaction identifier
data.reactions[0].identifiers[0].value
# Out:
# '[S:1](=[O:4])(=[O:3])=[O:2].[S:5](=[O:9])(=[O:8])([OH:7])[OH:6]>>[OH:8][S:5]([OH:9])(=[O:7])=[O:6].[O:2]=[S:1](=[O:4])=[O:3] |f:2.3|'

# %%
data.name
# Out:
# 'uspto-grants-1993_09'

# %%
# Can also find ORD file just given the hash:
def open_ord(ord_hash):
    folder_path = '/Users/danielwigh/projects_local/ORDerly_project/ORDerly/data/ord'
    # look for files within that folder path or deeper for a file that contains the ord_hash
    for root, dirs, files in os.walk(folder_path):
        for file in files:
            if fnmatch.fnmatch(file, f'*{ord_hash}*'):
                filepath = os.path.join(root, file)
                data = message_helpers.load_message(filepath, dataset_pb2.Dataset)
                return data
    raise FileNotFoundError(f"No file found containing {ord_hash} in the name.")

# %%
data = open_ord('ord_dataset-0b70410902ae4139bd5d334881938f69')
data.name
# Out:
# 'uspto-grants-1986_09'

# %%
pwd
# Out:
# '/Users/danielwigh/projects_local/ORDerly_project/ORDerly/notebooks'

# %% [markdown]
# # Inspect extracted data from ORD file

# %%
import pandas as pd

# %%
path = "../data/orderly/uspto_no_trust/extracted_ords/uspto-grants-1986_09.parquet"
df = pd.read_parquet(path)

# %%
# find df['rxn_str'] which contains [Pd] and [C]

filtered_df = df[df['rxn_str'].str.contains('[H][H]', regex=False) & df['rxn_str'].str.contains('\[C\]')]
filtered_df['rxn_str']
# Out:
# 277    C(OC([N:11]1[CH2:23][CH2:22][CH2:21][C@H:12]1[...
# 279    C(OC([N:11]1[CH2:15][CH2:14][CH2:13][C@H:12]1[...
# 582    [CH3:1][C:2]1[O:3][C:4](=[O:14])[C:5](=[CH:7][...
# Name: rxn_str, dtype: object

# %%
df.loc[277]['rxn_str']
# Out:
# 'C(OC([N:11]1[CH2:23][CH2:22][CH2:21][C@H:12]1[C:13]([N:15]1[CH2:20][CH2:19][O:18][CH2:17][CH2:16]1)=[O:14])=O)C1C=CC=CC=1.[H][H]>C(O)C.[C].[Pd]>[NH:11]1[CH2:23][CH2:22][CH2:21][C@H:12]1[C:13]([N:15]1[CH2:20][CH2:19][O:18][CH2:17][CH2:16]1)=[O:14]'

# %%
'C(OC([N:11]1[CH2:23][CH2:22][CH2:21][C@H:12]1[C:13]([N:15]1[CH2:20][CH2:19][O:18][CH2:17][CH2:16]1)=[O:14])=O)C1C=CC=CC=1.[H][H]>C(O)C.[C].[Pd]>[NH:11]1[CH2:23][CH2:22][CH2:21][C@H:12]1[C:13]([N:15]1[CH2:20][CH2:19][O:18][CH2:17][CH2:16]1)=[O:14]'

# %%
df.loc[277]['yield_000']
# Out:
# 98.7

# %%
df.loc[262]['yield_000']
# Out:
# 99.7

# %%
ag
# Out:
# 'CO.[C].[Pd]'

# %% [markdown]
# # Inspect cleaned data from ORD file

# %%
import pandas as pd

# %%
path = "../data/orderly/datasets/orderly_no_trust_no_map_train.parquet"
df = pd.read_parquet(path)

# %%
df['rxn_str'][0]
# Out:
# '[Cl:1][C:2]1[N:3]=[CH:4][C:5]2[C:10]([CH:11]=1)=[C:9]([N+:12]([O-])=O)[CH:8]=[CH:7][CH:6]=2.O.[OH-].[Na+]>C(O)(=O)C.[Fe]>[Cl:1][C:2]1[N:3]=[CH:4][C:5]2[C:10]([CH:11]=1)=[C:9]([NH2:12])[CH:8]=[CH:7][CH:6]=2'

# %% [markdown]
# # Download ORD

# %%
import pathlib
import zipfile

import pandas as pd
import requests


def download_benchmark(
    benchmark_zip_file="orderly_benchmark.zip",
    benchmark_directory="orderly_benchmark/",
    version=2,
):
    figshare_url = (
        f"https://figshare.com/ndownloader/articles/23298467/versions/{version}"
    )
    print(f"Downloading benchmark from {figshare_url} to {benchmark_zip_file}")
    r = requests.get(figshare_url, allow_redirects=True)
    with open(benchmark_zip_file, "wb") as f:
        f.write(r.content)

    print("Unzipping benchmark")
    benchmark_directory = pathlib.Path(benchmark_directory)
    benchmark_directory.mkdir(parents=True, exist_ok=True)
    with zipfile.ZipFile(benchmark_zip_file, "r") as zip_ref:
        zip_ref.extractall(benchmark_directory)


download_benchmark()
train_df = pd.read_parquet("orderly_benchmark/orderly_benchmark_train.parquet")
test_df = pd.read_parquet("orderly_benchmark/orderly_benchmark_test.parquet")
# Out:
# Downloading benchmark from https://figshare.com/ndownloader/articles/23298467/versions/2 to orderly_benchmark.zip
# Unzipping benchmark

# %%
train_df
# Out:
#                             agent_000                      agent_001  \
# 332116                          [OH-]                          [Na+]
# 109219                          [OH-]                         [Pd+2]
# 212362  c1ccc(P(c2ccccc2)c2ccccc2)cc1                           None
# 198710                           [Fe]                             Cl
# 243552    CC(C)OC(=O)/N=N/C(=O)OC(C)C  c1ccc(P(c2ccccc2)c2ccccc2)cc1
# ...                               ...                            ...
# 232549                       [Li]CCCC                           None
# 208488                          [Na+]                      [BH3-]C#N
# 222435                             Cl                          [Na+]
# 225524       Cc1ccc(S(=O)(=O)[O-])cc1                   c1cc[nH+]cc1
# 225523          Cc1ccc(S(=O)(=O)O)cc1                           None
#
#        agent_002 date_of_experiment  \
# 332116      None                NaT
# 109219      None                NaT
# 212362      None                NaT
# 198710      None                NaT
# 243552      None                NaT
# ...          ...                ...
# 232549      None                NaT
# 208488      None                NaT
# 222435     [OH-]                NaT
# 225524      None                NaT
# 225523      None                NaT
#
#                                  extracted_from_file          grant_date  \
# 332116  ord_dataset-bcc0b01d4f58457a8733b10a099f43ba 2015-01-01 00:10:00
# 109219  ord_dataset-e967d076b4894c2c854795f019ed3c39 2002-01-01 00:06:00
# 212362  ord_dataset-3af92aec23dc4810b92eb0d8c60023ee 2011-01-01 00:03:00
# 198710  ord_dataset-f886e51ba1484c76a94bce1482f1eab9 2010-01-01 00:07:00
# 243552  ord_dataset-9cd817a75dfc4fe7ad19d4232772d5ff 2012-01-01 00:07:00
# ...                                              ...                 ...
# 232549  ord_dataset-aaeaab5f3720492494c1cbbdd0ed2820 2012-01-01 00:02:00
# 208488  ord_dataset-136cfada6ce247b4919085a57363459e 2011-01-01 00:01:00
# 222435  ord_dataset-52a37d876ddb453e86de0c15fa233d29 2011-01-01 00:09:00
# 225524  ord_dataset-375a420ee9b042918ddca20f02df37d3 2011-01-01 00:11:00
# 225523  ord_dataset-375a420ee9b042918ddca20f02df37d3 2011-01-01 00:11:00
#
#         is_mapped                                  procedure_details  \
# 332116       True  To N-[6-(1-tert-butyloxycarbonylpiperidin-4-yl...
# 109219       True  A solution of 240 mg (0.50 mmol) of 3-bromo-4-...
# 212362       True  A solution of triphenylphosphine (469 mg, 1.79...
# 198710       True  To a solution of methyl N-methyl-N-[(4′-nitro-...
# 243552       True  DIAD (23.95 ml, 123 mmol) was added dropwise t...
# ...           ...                                                ...
# 232549       True  To a solution of DIPA (15.5 mL) in THF (300 mL...
# 208488       True  To a cold solution of methyl indole-5-carboxyl...
# 222435       True  Before the start of the reaction, the loop rea...
# 225524       True  A solution of N-{3-[1,1-Dimethyl-2-(tetrahydro...
# 225523       True  A solution of 98 g (0.21 mol) of N-{3-[1,1-dim...
#
#                                               product_000  \
# 332116  Cc1c(C(=O)Nc2ccc(C3CCNCC3)nc2)cnn1-c1ccc(C(F)(...
# 109219  CN1C(=O)CC(c2c(CCCCc3cc4ccccc4[nH]3)[nH]c3cccc...
# 212362                                 BrCc1cc2ccccc2cc1I
# 198710  COC(=O)[C@H](C(C)C)N(C)C(=O)c1ccc(-c2ccc(N)cc2...
# 243552              COC(=O)c1cccc(OC)c1OCCNC(=O)OC(C)(C)C
# ...                                                   ...
# 232549                           COc1ccc2ncc(F)c(C=O)c2c1
# 208488                             COC(=O)c1ccc2c(c1)CCN2
# 222435                            CC(C)(C)OOC(=O)c1ccccc1
# 225524   CC(C)(CO)c1cc(NC(=O)C(C)(C)S(=O)(=O)C2CCOCC2)on1
# 225523   CC(C)(CO)c1cc(NC(=O)C(C)(C)S(=O)(=O)C2CCOCC2)on1
#
#                                              reactant_000  \
# 332116  Cc1c(C(=O)Nc2ccc(C3CCN(C(=O)OC(C)(C)C)CC3)nc2)...
# 109219  CN1C(=O)C(Br)=C(c2c(CCCCc3cc4ccccc4[nH]3)[nH]c...
# 212362                                      BrC(Br)(Br)Br
# 198710  COC(=O)[C@H](C(C)C)N(C)C(=O)c1ccc(-c2ccc([N+](...
# 243552                                 CC(C)(C)OC(=O)NCCO
# ...                                                   ...
# 232549                                           CN(C)C=O
# 208488                            COC(=O)c1ccc2[nH]ccc2c1
# 222435                                         CC(C)(C)OO
# 225524  CC(C)(COC1CCCCO1)c1cc(NC(=O)C(C)(C)S(=O)(=O)C2...
# 225523  CC(C)(COC1CCCCO1)c1cc(NC(=O)C(C)(C)S(=O)(=O)C2...
#
#                 reactant_001  \
# 332116                  NULL
# 109219                  NULL
# 212362     OCc1cc2ccccc2cc1I
# 198710                  NULL
# 243552  COC(=O)c1cccc(OC)c1O
# ...                      ...
# 232549   COc1ccc2ncc(F)cc2c1
# 208488                  NULL
# 222435       O=C(Cl)c1ccccc1
# 225524                  NULL
# 225523                  NULL
#
#                                                   rxn_str  rxn_time  \
# 332116  C(OC([N:8]1[CH2:13][CH2:12][CH:11]([C:14]2[N:1...      2.50
# 109219  Br[C:2]1[C:3](=[O:31])[N:4]([CH3:30])[C:5](=[O...       NaN
# 212362  C1(P(C2C=CC=CC=2)C2C=CC=CC=2)C=CC=CC=1.[C:20](...      4.00
# 198710  [CH3:1][N:2]([C:11]([C:13]1[CH:18]=[CH:17][C:1...       NaN
# 243552  CC(OC(/N=N/C(OC(C)C)=O)=O)C.[OH:15][CH2:16][CH...      0.50
# ...                                                   ...       ...
# 232549  [Li]CCCC.[F:6][C:7]1[CH:8]=[N:9][C:10]2[C:15](...      0.08
# 208488  [NH:1]1[C:9]2[C:4](=[CH:5][C:6]([C:10]([O:12][...       NaN
# 222435  [C:1]([O:5][OH:6])([CH3:4])([CH3:3])[CH3:2].[O...       NaN
# 225524  [CH3:1][C:2]([C:12]1[CH:16]=[C:15]([NH:17][C:1...       NaN
# 225523  [CH3:1][C:2]([C:12]1[CH:16]=[C:15]([NH:17][C:1...       NaN
#
#            solvent_000 solvent_001  temperature  yield_000
# 332116  O=C(O)C(F)(F)F       ClCCl         25.0       89.4
# 109219              CO        None          NaN        NaN
# 212362           ClCCl        None         25.0        NaN
# 198710             CCO        None          NaN       75.8
# 243552         C1CCOC1        None          NaN        NaN
# ...                ...         ...          ...        ...
# 232549         C1CCOC1        None          0.0       52.0
# 208488         CC(=O)O        None         25.0       80.2
# 222435               O        None          NaN       95.3
# 225524             CCO        None          NaN       81.0
# 225523           ClCCl         CCO          NaN       82.7
#
# [322976 rows x 17 columns]

# %%
train_2_df = pd.read_parquet("/Users/dsw46/Projects_local/orderly_reproduce/data/orderly/orderly_ord_train.parquet")

# %%
train_2_df
# Out:
#                                                 agent_000  \
# index
# 79574                                                [Pd]
# 148136                                    CCN=C=NCCCN(C)C
# 79634                                               [Na+]
# 329451  c1ccc([P](c2ccccc2)(c2ccccc2)[Pd]([P](c2ccccc2...
# 359709                                               [H-]
# ...                                                   ...
# 182938                                               [H-]
# 123321                                              [Na+]
# 35293                    CC1(C)C2CCC1(CS(=O)(=O)O)C(=O)C2
# 392918                                           O=[Pt]=O
# 92455                                                [H-]
#
#                         agent_001       agent_002 date_of_experiment  \
# index
# 79574                         [C]            None                NaT
# 148136                         Cl  On1nnc2ccccc21                NaT
# 79634   [O-][I+3]([O-])([O-])[O-]            None                NaT
# 329451              O=C([O-])[O-]            [K+]                NaT
# 359709                      [Na+]            None                NaT
# ...                           ...             ...                ...
# 182938                      [Na+]            None                NaT
# 123321                      [OH-]            None                NaT
# 35293    CCCC[N+](CCCC)(CCCC)CCCC           other                NaT
# 392918                       None            None                NaT
# 92455                       [Na+]            None                NaT
#
#                                  extracted_from_file          grant_date  \
# index
# 79574   ord_dataset-a6643d22de674f30a85ba57198b82644 1995-01-01 00:03:00
# 148136  ord_dataset-82e842e611ef4a05b6e7f9ea0a46d52d 2003-01-01 00:07:00
# 79634   ord_dataset-a6643d22de674f30a85ba57198b82644 1995-01-01 00:03:00
# 329451  ord_dataset-cfad8b3f00044bcda60a96b019f09872 2013-01-01 00:08:00
# 359709  ord_dataset-a86112d52cd54525a5e36d41f18aced2 2014-01-01 00:07:00
# ...                                              ...                 ...
# 182938  ord_dataset-844a22e1fcab44a5b59c5e2922b2855a 2007-01-01 00:01:00
# 123321  ord_dataset-18e9ed24dbd44e98b33bdc22aa7580a8 2001-01-01 00:04:00
# 35293   ord_dataset-1895fe091c3f47afa1ee96a41a250de4 1986-01-01 00:05:00
# 392918  ord_dataset-35c51552812941cda45194a013d34bb9 2015-01-01 00:08:00
# 92455   ord_dataset-c2ad1656a3ca4d08888ffb6e3f3a2742 1997-01-01 00:05:00
#
#         is_mapped                                  procedure_details  \
# index
# 79574        True  In a mixture of 18 ml of ethanol and 9 ml of N...
# 148136       True  A mixture of 5-[5-(2,6-dichloro-phenylmethanes...
# 79634        True  A solution of sodium periodate (0.214 g.; 0.00...
# 329451       True  As depicted in Reaction 5, 15 g (46 mmol) of 3...
# 359709       True  Sodium hydride (60% in oil, 19.41 mg, 0.485 mm...
# ...           ...                                                ...
# 182938       True  In DMF (8.0 ml) was suspended sodium hydride (...
# 123321       True  A mixture of 6-benzyloxy-1,3-benzoxathiol-2-on...
# 35293        True  To a stirred solution of 3.58 g of (3S)-2-oxo-...
# 392918       True  2-Aminopropan-1-ol (5 g, 66.57 mmol) and 1-hyd...
# 92455        True  To a suspension of 12 g of 3,5-dibromopyridine...
#
#                                               product_000 product_001  ...  \
# index                                                                  ...
# 79574                     Nc1ccccc1Oc1cccc(-c2nnn[nH]2)c1        NULL  ...
# 148136  Cc1[nH]c(/C=C2\C(=O)Nc3ccc(S(=O)(=O)Cc4c(Cl)cc...        NULL  ...
# 79634    COc1ccc2c(c1)C(CC(=O)O)=C(C)C2=Cc1ccc(S(C)=O)cc1        NULL  ...
# 329451       c1ccc(-c2ccc3[nH]c4ccc(-c5ccccc5)cc4c3c2)cc1        NULL  ...
# 359709       CC(C)(C)OC(=O)CN1C[C@@H]2COCCN2c2nc(Cl)ncc21        NULL  ...
# ...                                                   ...         ...  ...
# 182938                           CCn1cc(C(=O)OC)c2ccccc21        NULL  ...
# 123321                             Oc1cc(OCc2ccccc2)ccc1S        NULL  ...
# 35293                                 Oc1cccc2ccc[nH+]c12        NULL  ...
# 392918                                      CC(CO)NC(C)CO        NULL  ...
# 92455                                      COc1cncc(Br)c1        NULL  ...
#
#                                                   rxn_str rxn_time  \
# index
# 79574   [N+:1]([C:4]1[CH:21]=[CH:20][CH:19]=[CH:18][C:...      NaN
# 148136  [Cl:1][C:2]1[CH:7]=[CH:6][CH:5]=[C:4]([Cl:8])[...     72.0
# 79634   I([O-])(=O)(=O)=O.[Na+].[OH2:7].[CH3:8][O:9][C...      8.0
# 329451  Br[C:2]1[CH:3]=[CH:4][C:5]2[NH:6][C:7]3[C:12](...      NaN
# 359709  [H-].[Na+].[Cl:3][C:4]1[N:13]=[CH:12][C:11]2[N...      0.5
# ...                                                   ...      ...
# 182938  [H-].[Na+].[NH:3]1[C:11]2[C:6](=[CH:7][CH:8]=[...      NaN
# 123321  [CH2:1]([O:8][C:9]1[CH:18]=[CH:17][C:12]2[S:13...     16.0
# 35293   C([N+](CCCC)(CCCC)CCCC)CCC.[O:18]=[C:19]1[C@@H...      NaN
# 392918  [NH2:1][CH:2]([CH3:5])[CH2:3][OH:4].[OH:6][CH2...     24.0
# 92455   [Br:1][C:2]1[CH:3]=[N:4][CH:5]=[C:6](Br)[CH:7]...      1.0
#
#        solvent_000 solvent_001 temperature yield_000 yield_001 yield_002  \
# index
# 79574          CCO    CN(C)C=O         NaN      96.9       NaN       NaN
# 148136    CN(C)C=O        None        40.0       NaN       NaN       NaN
# 79634      CC(C)=O          CO        25.0       NaN       NaN       NaN
# 329451   Cc1ccccc1        None         NaN      73.0       NaN       NaN
# 359709    CN(C)C=O           O        25.0      67.2       NaN       NaN
# ...            ...         ...         ...       ...       ...       ...
# 182938    CN(C)C=O           O         0.0       NaN       NaN       NaN
# 123321          CO        None        25.0       NaN       NaN       NaN
# 35293     CC(Cl)Cl        None         NaN       NaN       NaN       NaN
# 392918         CCO        None        25.0       NaN       NaN       NaN
# 92455     CN(C)C=O        None        60.0       NaN       NaN       NaN
#
#        yield_003  yield_004
# index
# 79574        NaN        NaN
# 148136       NaN        NaN
# 79634        NaN        NaN
# 329451       NaN        NaN
# 359709       NaN        NaN
# ...          ...        ...
# 182938       NaN        NaN
# 123321       NaN        NaN
# 35293        NaN        NaN
# 392918       NaN        NaN
# 92455        NaN        NaN
#
# [387287 rows x 28 columns]

# %% [markdown]
# # Download data from TDC

# %%
# Inspect the retrosynthesis dataset

from tdc.generation import RetroSyn
data = RetroSyn(name = 'USPTO')
split = data.get_split()
# Out:
# Downloading...
# 100%|██████████| 795M/795M [01:29<00:00, 8.88MiB/s]
# Loading...
# Done!

# %%
len(split['train'])+len(split['test'])
# Out:
# 997415

# %%
from tdc.generation import Reaction
data = Reaction(name = 'USPTO')
split = data.get_split()
# Out:
# Found local copy...
# Loading...
# Done!

# %%
len(split['train'])+len(split['test'])
# Out:
# 997415
