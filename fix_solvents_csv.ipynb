# %% [markdown]
# # Check that solvents.csv is well set up

# %%
import pandas as pd
from rdkit import Chem

# %%
solvents_df = pd.read_csv('orderly/data/solvents.csv')
solvents_df.columns
solvents_smiles = solvents_df['smiles']

# %%
# check all smiles are canonicalisable
# Canonicalise and remove stoichiometry
def clean_smiles(smiles):
    mol = Chem.MolFromSmiles(smiles)
    if mol is None:
        print(smiles)
        return smiles
    else:
        return Chem.MolToSmiles(mol, isomericSmiles=False)

# Apply the function to all columns in the DataFrame
solvents_smiles.apply(clean_smiles)
# Out:
# 0           C1=CCCC=CCC1
# 1               CC=CC=CC
# 2        ClC(Cl)c1ccccc1
# 3                C=CC=CC
# 4                CC=CC#N
#              ...
# 615    CC1(C)CCC(C)(C)O1
# 616         Cc1ccc(C)cc1
# 617           Cc1ccccc1C
# 618         Cc1cccc(C)c1
# 619         Cc1ccc(C)cc1
# Name: smiles, Length: 620, dtype: object

# %%
solvents_df
# Out:
#                    solvent_name_1             solvent_name_2 solvent_name_3  \
# 0     (1z,5z)-cycloocta-1,5-diene         1,5-cyclooctadiene            NaN
# 1           (2e,4e)-2,4-hexadiene  trans,trans-2,4-hexadiene            NaN
# 2         (dichloromethyl)benzene   (dichloromethyl)-benzene            NaN
# 3              (e)-1,3-pentadiene       1-trans-3-pentadiene            NaN
# 4             (e)-2-butenenitrile                        NaN            NaN
# ..                            ...                        ...            ...
# 615  tetramethyl tetrahydrofurane                      tmthf            NaN
# 616                       xylenes                      xylol            NaN
# 617                      o-xylene                        NaN            NaN
# 618                      m-xylene                        NaN            NaN
# 619                      p-xylene                        NaN            NaN
#
#      cas_number chemical_formula             smiles  \
# 0      111-78-4            C8H12       C1=CCCC=CCC1
# 1     5194-51-4            C6H10           CC=CC=CC
# 2       98-87-3          C7H6Cl2    ClC(Cl)c1ccccc1
# 3     2004-70-8             C5H8            C=CC=CC
# 4      627-26-9            C4H5N            CC=CC#N
# ..          ...              ...                ...
# 615  15045-43-9           C8H16O  CC1(CCC(O1)(C)C)C
# 616   1330-20-7            C8H10       Cc1ccc(C)cc1
# 617         NaN              NaN     Cc1c(C)cccc1\t
# 618         NaN              NaN     Cc1cc(C)ccc1\t
# 619         NaN              NaN       Cc1ccc(C)cc1
#
#                                                 source
# 0                   https://doi.org/10.1039/C9SC01844A
# 1                   https://doi.org/10.1039/C9SC01844A
# 2                   https://doi.org/10.1039/C9SC01844A
# 3                   https://doi.org/10.1039/C9SC01844A
# 4                   https://doi.org/10.1039/C9SC01844A
# ..                                                 ...
# 615  MOLECULES FROM https://github.com/sustainable-...
# 616  MOLECULES FROM https://github.com/sustainable-...
# 617  MOLECULES FROM https://github.com/sustainable-...
# 618  MOLECULES FROM https://github.com/sustainable-...
# 619  MOLECULES FROM https://github.com/sustainable-...
#
# [620 rows x 7 columns]

# %% [markdown]
# # Fixing solvents csv

# %%
import pandas as pd
from rdkit import Chem
import numpy as np

# %%
solvents_df = pd.read_csv('orderly/data/solvents.csv')
df1 = pd.read_csv('orderly/data/subset_1.csv')
df2 = pd.read_csv('orderly/data/subset_2.csv')

# %%
# create set of strings in df1
strings_to_remove = df1[['solvent_name_1', 'solvent_name_2', 'solvent_name_3']].values.flatten().tolist()
strings_to_remove = [x for x in strings_to_remove if not pd.isna(x)]

# %%
df2 = df2[~df2['solvent_name_1'].isin(strings_to_remove)]
df2 = df2[~df2['solvent_name_2'].isin(strings_to_remove)]
df2 = df2[~df2['solvent_name_3'].isin(strings_to_remove)]

# %%
df2.to_csv('orderly/data/subset_2_.csv', index=False)

# %% [markdown]
# # Check for duplicates in the three name columns

# %%
# we want to look for duplicates in the 'solvent_name' columns
solvent_names = solvents_df[['solvent_name_1', 'solvent_name_2', 'solvent_name_3']]
# check for duplicates
duplicates = solvent_names.duplicated()

# print duplicate rows
print(solvent_names[duplicates])
# Out:
# Empty DataFrame
# Columns: [solvent_name_1, solvent_name_2, solvent_name_3]
# Index: []

# %%
solvent_names_list = solvent_names.values.flatten().tolist()
solvent_names_list = [x for x in solvent_names_list if not pd.isna(x)]

# %%
print(len(solvent_names_list))
# Out:
# 915

# %%
print(len(set(solvent_names_list)))
# Out:
# 915

# %%
# manually remove duplicates to ensure we don't lose any data
# create dictionary to count occurrences
count_dict = {}
for item in solvent_names_list:
    count_dict[item] = count_dict.get(item, 0) + 1

# extract elements with count of 2 or more
duplicates = [item for item, count in count_dict.items() if count >= 2]

# %%
len(duplicates)
# Out:
# 0

# %%
duplicates
# Out:
# []

# %%
# check for any trailing or leading spaces
for s in solvent_names_list:
    if s != s.strip():
        print(s)

# %%
# # make lower
# # make specified columns lower case
# solvents_df[['solvent_name_1', 'solvent_name_2', 'solvent_name_3']] = solvents_df[['solvent_name_1', 'solvent_name_2', 'solvent_name_3']].applymap(lambda x: x.lower() if type(x) == str else x)

# # save to csv
# solvents_df.to_csv('orderly/data/solvents.csv', index=False)

# %% [markdown]
# # Use pura on each column

# %%
import pandas as pd

# Import pura
from pura.resolvers import resolve_identifiers
from pura.compound import CompoundIdentifierType
from pura.services import PubChem, CIR, Opsin, CAS, ChemSpider, STOUT

solvents_df = pd.read_csv('orderly/data/solvents.csv')
# Out:
# 2023-04-26 18:41:43.245303: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
def apply_pura_name_to_smiles(lst, services=[PubChem(autocomplete=True), Opsin(), CIR(),]):
    resolved = resolve_identifiers(
        lst,
        input_identifer_type=CompoundIdentifierType.NAME,
        output_identifier_type=CompoundIdentifierType.SMILES,
        services=services,
        agreement=2,
        silent=True,
    )
    return resolved

def apply_pura_cas_to_smiles(lst):
    resolved = resolve_identifiers(
        lst,
        input_identifer_type=CompoundIdentifierType.CAS_NUMBER,
        output_identifier_type=CompoundIdentifierType.SMILES,
        services=[CAS()],
        agreement=1,
        silent=True,
    )
    return resolved

# %%
col1_lst_1 = solvents_df['solvent_name_1'].dropna().tolist()
col1_lst_2 = solvents_df['solvent_name_2'].dropna().tolist()
col1_lst_3 = solvents_df['solvent_name_3'].dropna().tolist()
names = col1_lst_1 + col1_lst_2 + col1_lst_3

# %%
len(set(names)) == len(names)
print(len(names))
# Out:
# 915

# %%
names_pura = apply_pura_name_to_smiles(names)
# Out:
# Batch 0 Progress: 100%|██████████| 100/100 [00:20<00:00,  5.00it/s]
# Batch 1 Progress: 100%|██████████| 100/100 [00:09<00:00, 10.31it/s]
# Batch:  20%|██        | 2/10 [00:29<01:51, 13.96s/it]ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='d-carvone' details=None: Not Found
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='4,n,n-trimethylaniline' details=None: Not Found
# ERROR:pura.resolvers:Not sufficient agreement for identifiers=[CompoundIdentifier(identifier_type=<CompoundIdentifierType.NAME: 6>, value='d-carvone', details=None)] amount=None mass=None volume=None (outputs: [[CompoundIdentifier(identifier_type=<CompoundIdentifierType.SMILES: 2>, value='C=C(C)[C@H]1CC=C(C)C(=O)C1', details=None)]])
# ERROR:pura.resolvers:Not sufficient agreement for identifiers=[CompoundIdentifier(identifier_type=<CompoundIdentifierType.NAME: 6>, value='4,n,n-trimethylaniline', details=None)] amount=None mass=None volume=None (outputs: [[CompoundIdentifier(identifier_type=<CompoundIdentifierType.SMILES: 2>, value='Cc1ccc(N(C)C)cc1', details=None)]])
# Batch 2 Progress: 100%|██████████| 100/100 [00:09<00:00, 10.20it/s]
# Batch:  30%|███       | 3/10 [00:39<01:24, 12.07s/it]ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='n,n-dimethylcyclohexylamine' details=None: Not Found
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='n,n-dimethylacetamide' details=None: Not Found
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='n,n-dimethylaniline' details=None: Not Found
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value="n,n,n',n'-tetramethylurea" details=None: Not Found
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='n,n-dimethylformamide' details=None: Not Found
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='n,n-diethylaniline' details=None: Not Found
# ERROR:pura.resolvers:Not sufficient agreement for identifiers=[CompoundIdentifier(identifier_type=<CompoundIdentifierType.NAME: 6>, value="n,n,n',n'-tetramethylurea", details=None)] amount=None mass=None volume=None (outputs: [[CompoundIdentifier(identifier_type=<CompoundIdentifierType.SMILES: 2>, value='CN(C)C(=O)N(C)C', details=None)]])
# ERROR:pura.resolvers:Not sufficient agreement for identifiers=[CompoundIdentifier(identifier_type=<CompoundIdentifierType.NAME: 6>, value='n,n-dimethylcyclohexylamine', details=None)] amount=None mass=None volume=None (outputs: [[CompoundIdentifier(identifier_type=<CompoundIdentifierType.SMILES: 2>, value='CN(C)C1CCCCC1', details=None)]])
# ERROR:pura.resolvers:Not sufficient agreement for identifiers=[CompoundIdentifier(identifier_type=<CompoundIdentifierType.NAME: 6>, value='n,n-dimethylacetamide', details=None)] amount=None mass=None volume=None (outputs: [[CompoundIdentifier(identifier_type=<CompoundIdentifierType.SMILES: 2>, value='CC(=O)N(C)C', details=None)]])
# ERROR:pura.resolvers:Not sufficient agreement for identifiers=[CompoundIdentifier(identifier_type=<CompoundIdentifierType.NAME: 6>, value='n,n-dimethylaniline', details=None)] amount=None mass=None volume=None (outputs: [[CompoundIdentifier(identifier_type=<CompoundIdentifierType.SMILES: 2>, value='CN(C)c1ccccc1', details=None)]])
# ERROR:pura.resolvers:Not sufficient agreement for identifiers=[CompoundIdentifier(identifier_type=<CompoundIdentifierType.NAME: 6>, value='n,n-diethylaniline', details=None)] amount=None mass=None volume=None (outputs: [[CompoundIdentifier(identifier_type=<CompoundIdentifierType.SMILES: 2>, value='CCN(CC)c1ccccc1', details=None)]])
# ERROR:pura.resolvers:Not sufficient agreement for identifiers=[CompoundIdentifier(identifier_type=<CompoundIdentifierType.NAME: 6>, value='n,n-dimethylformamide', details=None)] amount=None mass=None volume=None (outputs: [[CompoundIdentifier(identifier_type=<CompoundIdentifierType.SMILES: 2>, value='CN(C)C=O', details=None)]])
# Batch 3 Progress: 100%|██████████| 100/100 [00:19<00:00,  5.08it/s]
# Batch:  40%|████      | 4/10 [00:59<01:30, 15.08s/it]ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='butyl cellosolve' details=None: Not Found
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='butoxytriglycol' details=None: Not Found
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='butyl carbitol' details=None: Not Found
# ERROR:pura.resolvers:Not sufficient agreement for identifiers=[CompoundIdentifier(identifier_type=<CompoundIdentifierType.NAME: 6>, value='butyl cellosolve', details=None)] amount=None mass=None volume=None (outputs: [[CompoundIdentifier(identifier_type=<CompoundIdentifierType.SMILES: 2>, value='CCCCOCCO', details=None)]])
# ERROR:pura.resolvers:Not sufficient agreement for identifiers=[CompoundIdentifier(identifier_type=<CompoundIdentifierType.NAME: 6>, value='1,8-diazabicycloundec-7-ene', details=None)] amount=None mass=None volume=None (outputs: [[CompoundIdentifier(identifier_type=<CompoundIdentifierType.SMILES: 2>, value='C1=NCCCN(C2CCCCCCCCCC2)CCCCC1', details=None)], [CompoundIdentifier(identifier_type=<CompoundIdentifierType.SMILES: 2>, value='C1=CCCCC(N2CCCCCC=NCCC2)CCCCC1', details=None)]])
# ERROR:pura.resolvers:Not sufficient agreement for identifiers=[CompoundIdentifier(identifier_type=<CompoundIdentifierType.NAME: 6>, value='butyl carbitol', details=None)] amount=None mass=None volume=None (outputs: [[CompoundIdentifier(identifier_type=<CompoundIdentifierType.SMILES: 2>, value='CCCCOCCOCCO', details=None)]])
# ERROR:pura.resolvers:Not sufficient agreement for identifiers=[CompoundIdentifier(identifier_type=<CompoundIdentifierType.NAME: 6>, value='butoxytriglycol', details=None)] amount=None mass=None volume=None (outputs: [[CompoundIdentifier(identifier_type=<CompoundIdentifierType.SMILES: 2>, value='CCCCOCCOCCOCCO', details=None)]])
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='butyl carbitol acetate' details=None: Not Found
# ERROR:pura.resolvers:Not sufficient agreement for identifiers=[CompoundIdentifier(identifier_type=<CompoundIdentifierType.NAME: 6>, value='butyl carbitol acetate', details=None)] amount=None mass=None volume=None (outputs: [[CompoundIdentifier(identifier_type=<CompoundIdentifierType.SMILES: 2>, value='CCCCOCCOCCOC(C)=O', details=None)]])
# Batch 4 Progress: 100%|██████████| 100/100 [00:10<00:00,  9.59it/s]
# Batch:  50%|█████     | 5/10 [01:09<01:07, 13.41s/it]ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='methyl carbitol' details=None: Not Found
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='mtbe' details=None: Not Found
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='butyl cellosolve acetate' details=None: Not Found
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='n-ethyl-n-isopropylpropan-2-amine' details=None: Not Found
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='proprionitrile' details=None: Not Found
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='hexyl carbitol' details=None: Not Found
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='dimethyl isosorbide' details=None: Not Found
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='hmpa' details=None: Not Found
# ERROR:pura.resolvers:Not sufficient agreement for identifiers=[CompoundIdentifier(identifier_type=<CompoundIdentifierType.NAME: 6>, value='proprionitrile', details=None)] amount=None mass=None volume=None (outputs: [[CompoundIdentifier(identifier_type=<CompoundIdentifierType.SMILES: 2>, value='CCC#N', details=None)], []])
# ERROR:pura.resolvers:Not sufficient agreement for identifiers=[CompoundIdentifier(identifier_type=<CompoundIdentifierType.NAME: 6>, value='dimethyl isosorbide', details=None)] amount=None mass=None volume=None (outputs: [[CompoundIdentifier(identifier_type=<CompoundIdentifierType.SMILES: 2>, value='COC1COC2C(OC)COC12', details=None)], [CompoundIdentifier(identifier_type=<CompoundIdentifierType.SMILES: 2>, value='CO[C@H]1CO[C@H]2[C@@H]1OC[C@H]2OC', details=None)]])
# /Users/dsw46/opt/anaconda3/envs/chemistry/lib/python3.10/site-packages/pura/compound.py:129: UserWarning: Warning: Compound is not electrically neutral based on its SMILES string.
#   warnings.warn(
# ERROR:pura.resolvers:Not sufficient agreement for identifiers=[CompoundIdentifier(identifier_type=<CompoundIdentifierType.NAME: 6>, value='2-ethylhexylacetate', details=None)] amount=None mass=None volume=None (outputs: [[CompoundIdentifier(identifier_type=<CompoundIdentifierType.SMILES: 2>, value='COC(=O)Cc1ccc(C)cc1', details=None)], [CompoundIdentifier(identifier_type=<CompoundIdentifierType.SMILES: 2>, value='CCCCC(CC)COC(C)=O', details=None)], [CompoundIdentifier(identifier_type=<CompoundIdentifierType.SMILES: 2>, value='CCCCC(CC)CCC(=O)[O-]', details=None)]])
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='propyl cellosolve' details=None: Not Found
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='carbitol' details=None: Not Found
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='tpm glycol ether' details=None: Not Found
# ERROR:pura.resolvers:Not sufficient agreement for identifiers=[CompoundIdentifier(identifier_type=<CompoundIdentifierType.NAME: 6>, value='tpm glycol ether', details=None)] amount=None mass=None volume=None (outputs: [[CompoundIdentifier(identifier_type=<CompoundIdentifierType.SMILES: 2>, value='CCOC(=O)CS', details=None)], []])
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='pgda glycol ether' details=None: Not Found
# ERROR:pura.resolvers:Not sufficient agreement for identifiers=[CompoundIdentifier(identifier_type=<CompoundIdentifierType.NAME: 6>, value='pgda glycol ether', details=None)] amount=None mass=None volume=None (outputs: [[CompoundIdentifier(identifier_type=<CompoundIdentifierType.SMILES: 2>, value='COc1ccccc1OCC(O)CO', details=None)], []])
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='pnb glycol ether' details=None: Not Found
# ERROR:pura.resolvers:Not sufficient agreement for identifiers=[CompoundIdentifier(identifier_type=<CompoundIdentifierType.NAME: 6>, value='pnb glycol ether', details=None)] amount=None mass=None volume=None (outputs: [[CompoundIdentifier(identifier_type=<CompoundIdentifierType.SMILES: 2>, value='COc1ccccc1OCC(O)CO', details=None)], []])
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='dpm glycol ether' details=None: Not Found
# ERROR:pura.resolvers:Not sufficient agreement for identifiers=[CompoundIdentifier(identifier_type=<CompoundIdentifierType.NAME: 6>, value='dpm glycol ether', details=None)] amount=None mass=None volume=None (outputs: [[CompoundIdentifier(identifier_type=<CompoundIdentifierType.SMILES: 2>, value='COc1ccccc1OCC(O)CO', details=None)], []])
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='tpnb glycol ether' details=None: Not Found
# ERROR:pura.resolvers:Not sufficient agreement for identifiers=[CompoundIdentifier(identifier_type=<CompoundIdentifierType.NAME: 6>, value='tpnb glycol ether', details=None)] amount=None mass=None volume=None (outputs: [[CompoundIdentifier(identifier_type=<CompoundIdentifierType.SMILES: 2>, value='Cc1ccccc1OCC1CO1', details=None)], []])
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='dpnb glycol ether' details=None: Not Found
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='tmu' details=None: Not Found
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='eph glycol ether' details=None: Not Found
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='pph glycol ether' details=None: Not Found
# ERROR:pura.resolvers:Not sufficient agreement for identifiers=[CompoundIdentifier(identifier_type=<CompoundIdentifierType.NAME: 6>, value='dpnb glycol ether', details=None)] amount=None mass=None volume=None (outputs: [[]])
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='pm glycol ether' details=None: Not Found
# ERROR:pura.resolvers:Not sufficient agreement for identifiers=[CompoundIdentifier(identifier_type=<CompoundIdentifierType.NAME: 6>, value='tmu', details=None)] amount=None mass=None volume=None (outputs: [[CompoundIdentifier(identifier_type=<CompoundIdentifierType.SMILES: 2>, value='CN(C)C(=O)N(C)C', details=None)]])
# ERROR:pura.resolvers:Not sufficient agreement for identifiers=[CompoundIdentifier(identifier_type=<CompoundIdentifierType.NAME: 6>, value='eph glycol ether', details=None)] amount=None mass=None volume=None (outputs: [[]])
# ERROR:pura.resolvers:Not sufficient agreement for identifiers=[CompoundIdentifier(identifier_type=<CompoundIdentifierType.NAME: 6>, value='pm glycol ether', details=None)] amount=None mass=None volume=None (outputs: [[]])
# ERROR:pura.resolvers:Not sufficient agreement for identifiers=[CompoundIdentifier(identifier_type=<CompoundIdentifierType.NAME: 6>, value='pph glycol ether', details=None)] amount=None mass=None volume=None (outputs: [[]])
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='pma glycol ether' details=None: Not Found
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='cyrene' details=None: Not Found
# ERROR:pura.resolvers:Not sufficient agreement for identifiers=[CompoundIdentifier(identifier_type=<CompoundIdentifierType.NAME: 6>, value='pma glycol ether', details=None)] amount=None mass=None volume=None (outputs: [[]])
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='dpma glycol ether' details=None: Not Found
# ERROR:pura.resolvers:Not sufficient agreement for identifiers=[CompoundIdentifier(identifier_type=<CompoundIdentifierType.NAME: 6>, value='cyrene', details=None)] amount=None mass=None volume=None (outputs: [[]])
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='nep' details=None: Not Found
# ERROR:pura.resolvers:Not sufficient agreement for identifiers=[CompoundIdentifier(identifier_type=<CompoundIdentifierType.NAME: 6>, value='dpma glycol ether', details=None)] amount=None mass=None volume=None (outputs: [[]])
# ERROR:pura.resolvers:Not sufficient agreement for identifiers=[CompoundIdentifier(identifier_type=<CompoundIdentifierType.NAME: 6>, value='nep', details=None)] amount=None mass=None volume=None (outputs: [[]])
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='dpnp glycol ether' details=None: Not Found
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='ipa' details=None: Not Found
# ERROR:pura.resolvers:Not sufficient agreement for identifiers=[CompoundIdentifier(identifier_type=<CompoundIdentifierType.NAME: 6>, value='dpnp glycol ether', details=None)] amount=None mass=None volume=None (outputs: [[]])
# ERROR:pura.resolvers:Not sufficient agreement for identifiers=[CompoundIdentifier(identifier_type=<CompoundIdentifierType.NAME: 6>, value='ipa', details=None)] amount=None mass=None volume=None (outputs: [[CompoundIdentifier(identifier_type=<CompoundIdentifierType.SMILES: 2>, value='CC(C)O', details=None)]])
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='pnp glycol ether' details=None: Not Found
# ERROR:pura.resolvers:Not sufficient agreement for identifiers=[CompoundIdentifier(identifier_type=<CompoundIdentifierType.NAME: 6>, value='pnp glycol ether', details=None)] amount=None mass=None volume=None (outputs: [[]])
# Batch 5 Progress: 100%|██████████| 100/100 [00:11<00:00,  8.52it/s]
# Batch:  60%|██████    | 6/10 [01:21<00:51, 12.84s/it]ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='tert-butylthiol' details=None: Not Found
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='dmpu' details=None: Not Found
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='p-limonene' details=None: Not Found
# ERROR:pura.resolvers:Not sufficient agreement for identifiers=[CompoundIdentifier(identifier_type=<CompoundIdentifierType.NAME: 6>, value='p-limonene', details=None)] amount=None mass=None volume=None (outputs: [[CompoundIdentifier(identifier_type=<CompoundIdentifierType.SMILES: 2>, value='C=C(C)C1CC=C(C)CC1', details=None)], []])
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='4-methylpentanitrile' details=None: Not Found
# ERROR:pura.resolvers:Not sufficient agreement for identifiers=[CompoundIdentifier(identifier_type=<CompoundIdentifierType.NAME: 6>, value='4-methylpentanitrile', details=None)] amount=None mass=None volume=None (outputs: [[CompoundIdentifier(identifier_type=<CompoundIdentifierType.SMILES: 2>, value='CC(C)CC(N)C#N', details=None)], [CompoundIdentifier(identifier_type=<CompoundIdentifierType.SMILES: 2>, value='CC(C)CCC#N', details=None)]])
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='1,4-dibrombenzene' details=None: Not Found
# ERROR:pura.resolvers:Not sufficient agreement for identifiers=[CompoundIdentifier(identifier_type=<CompoundIdentifierType.NAME: 6>, value='1,4-dibrombenzene', details=None)] amount=None mass=None volume=None (outputs: [[CompoundIdentifier(identifier_type=<CompoundIdentifierType.SMILES: 2>, value='Brc1ccc(Br)cc1', details=None)], []])
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='glycol diacetate' details=None: Not Found
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='1,8-cineole' details=None: Not Found
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='paraldehyde' details=None: Not Found
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='dmtt(dazomet)' details=None: Not Found
# ERROR:pura.resolvers:Not sufficient agreement for identifiers=[CompoundIdentifier(identifier_type=<CompoundIdentifierType.NAME: 6>, value='dmtt(dazomet)', details=None)] amount=None mass=None volume=None (outputs: [[CompoundIdentifier(identifier_type=<CompoundIdentifierType.SMILES: 2>, value='CN1CSC(=S)N(C)C1', details=None)], []])
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='aceticacidphenylmethylester' details=None: Not Found
# ERROR:pura.resolvers:Not sufficient agreement for identifiers=[CompoundIdentifier(identifier_type=<CompoundIdentifierType.NAME: 6>, value='aceticacidphenylmethylester', details=None)] amount=None mass=None volume=None (outputs: [[CompoundIdentifier(identifier_type=<CompoundIdentifierType.SMILES: 2>, value='CC(=O)OCCOc1ccccc1', details=None)], []])
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='1,4-butadiol' details=None: Not Found
# ERROR:pura.resolvers:Not sufficient agreement for identifiers=[CompoundIdentifier(identifier_type=<CompoundIdentifierType.NAME: 6>, value='1,4-butadiol', details=None)] amount=None mass=None volume=None (outputs: [[CompoundIdentifier(identifier_type=<CompoundIdentifierType.SMILES: 2>, value='CCCCC1C(=O)N(c2ccccc2)N(c2ccccc2)C1=O', details=None)], []])
# ERROR:pura.resolvers:Not sufficient agreement for identifiers=[CompoundIdentifier(identifier_type=<CompoundIdentifierType.NAME: 6>, value='dmpu', details=None)] amount=None mass=None volume=None (outputs: [[CompoundIdentifier(identifier_type=<CompoundIdentifierType.SMILES: 2>, value='CN1CCCN(C)C1=O', details=None)], [CompoundIdentifier(identifier_type=<CompoundIdentifierType.SMILES: 2>, value='O=C1N(CO)CCCN1CO', details=None)]])
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='n,n,4-trimethylaniline' details=None: Not Found
# ERROR:pura.resolvers:Not sufficient agreement for identifiers=[CompoundIdentifier(identifier_type=<CompoundIdentifierType.NAME: 6>, value='n,n,4-trimethylaniline', details=None)] amount=None mass=None volume=None (outputs: [[CompoundIdentifier(identifier_type=<CompoundIdentifierType.SMILES: 2>, value='Cc1ccc(N(C)C)cc1', details=None)]])
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='propylenecarbonate' details=None: Not Found
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='1-cis-2-trans-3-trimethylcyclopentane' details=None: Not Found
# ERROR:pura.resolvers:Not sufficient agreement for identifiers=[CompoundIdentifier(identifier_type=<CompoundIdentifierType.NAME: 6>, value='propylenecarbonate', details=None)] amount=None mass=None volume=None (outputs: [[]])
# ERROR:pura.resolvers:Not sufficient agreement for identifiers=[CompoundIdentifier(identifier_type=<CompoundIdentifierType.NAME: 6>, value='1-cis-2-trans-3-trimethylcyclopentane', details=None)] amount=None mass=None volume=None (outputs: [[]])
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='1-trans-3-pentadiene' details=None: Not Found
# ERROR:pura.resolvers:Not sufficient agreement for identifiers=[CompoundIdentifier(identifier_type=<CompoundIdentifierType.NAME: 6>, value='1-trans-3-pentadiene', details=None)] amount=None mass=None volume=None (outputs: [[]])
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='n-methylpentafluorobenzene' details=None: Not Found
# ERROR:pura.resolvers:Not sufficient agreement for identifiers=[CompoundIdentifier(identifier_type=<CompoundIdentifierType.NAME: 6>, value='isobutylformate', details=None)] amount=None mass=None volume=None (outputs: [[CompoundIdentifier(identifier_type=<CompoundIdentifierType.SMILES: 2>, value='CC(C)COC=O', details=None)], [CompoundIdentifier(identifier_type=<CompoundIdentifierType.SMILES: 2>, value='CC(C)CC(=O)[O-]', details=None)]])
# ERROR:pura.resolvers:Not sufficient agreement for identifiers=[CompoundIdentifier(identifier_type=<CompoundIdentifierType.NAME: 6>, value='n-methylpentafluorobenzene', details=None)] amount=None mass=None volume=None (outputs: [[]])
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='xylenes' details=None: Not Found
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value="1,1'-oxybis-2-ethoxy-ethane" details=None: Not Found
# /Users/dsw46/opt/anaconda3/envs/chemistry/lib/python3.10/site-packages/pura/compound.py:101: UserWarning: Warning: SMILES of a mixture, rather than a pure compound, was found.
#   warnings.warn(
# ERROR:pura.resolvers:Not sufficient agreement for identifiers=[CompoundIdentifier(identifier_type=<CompoundIdentifierType.NAME: 6>, value='xylenes', details=None)] amount=None mass=None volume=None (outputs: [[CompoundIdentifier(identifier_type=<CompoundIdentifierType.SMILES: 2>, value='CCc1ccccc1.Cc1ccc(C)cc1.Cc1cccc(C)c1.Cc1ccccc1C', details=None)]])
# ERROR:pura.resolvers:Not sufficient agreement for identifiers=[CompoundIdentifier(identifier_type=<CompoundIdentifierType.NAME: 6>, value="1,1'-oxybis-2-ethoxy-ethane", details=None)] amount=None mass=None volume=None (outputs: [[]])
# Batch 6 Progress: 100%|██████████| 100/100 [00:12<00:00,  7.96it/s]
# Batch:  70%|███████   | 7/10 [01:34<00:38, 12.75s/it]ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='ch2br2' details=None: Not Found
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='n-bucooh' details=None: Not Found
# ERROR:pura.resolvers:Not sufficient agreement for identifiers=[CompoundIdentifier(identifier_type=<CompoundIdentifierType.NAME: 6>, value='n-bucooh', details=None)] amount=None mass=None volume=None (outputs: [[CompoundIdentifier(identifier_type=<CompoundIdentifierType.SMILES: 2>, value='CCCCC(=O)O', details=None)], []])
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='ch2cl2' details=None: Not Found
# ERROR:pura.resolvers:Not sufficient agreement for identifiers=[CompoundIdentifier(identifier_type=<CompoundIdentifierType.NAME: 6>, value='ch2cl2', details=None)] amount=None mass=None volume=None (outputs: [[CompoundIdentifier(identifier_type=<CompoundIdentifierType.SMILES: 2>, value='ClCCl', details=None)], []])
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='ch3i' details=None: Not Found
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='aceticacidcyclohexylester' details=None: Not Found
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='cyanoaceticacidethylester' details=None: Not Found
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='2-hydroxypropanoicacidethylester' details=None: Not Found
# ERROR:pura.resolvers:Not sufficient agreement for identifiers=[CompoundIdentifier(identifier_type=<CompoundIdentifierType.NAME: 6>, value='aceticacidcyclohexylester', details=None)] amount=None mass=None volume=None (outputs: [[CompoundIdentifier(identifier_type=<CompoundIdentifierType.SMILES: 2>, value='CC(=O)OCCOc1ccccc1', details=None)], []])
# ERROR:pura.resolvers:Not sufficient agreement for identifiers=[CompoundIdentifier(identifier_type=<CompoundIdentifierType.NAME: 6>, value='cyanoaceticacidethylester', details=None)] amount=None mass=None volume=None (outputs: [[CompoundIdentifier(identifier_type=<CompoundIdentifierType.SMILES: 2>, value='CCCCCCCCCCCCCCCCCCCCCCCC(=O)OCC', details=None)], []])
# ERROR:pura.resolvers:Not sufficient agreement for identifiers=[CompoundIdentifier(identifier_type=<CompoundIdentifierType.NAME: 6>, value='2-hydroxypropanoicacidethylester', details=None)] amount=None mass=None volume=None (outputs: [[CompoundIdentifier(identifier_type=<CompoundIdentifierType.SMILES: 2>, value='CCOC(=N)C(C)O.Cl', details=None)], []])
# ERROR:pura.resolvers:Not sufficient agreement for identifiers=[CompoundIdentifier(identifier_type=<CompoundIdentifierType.NAME: 6>, value='n-hexylacetate', details=None)] amount=None mass=None volume=None (outputs: [[CompoundIdentifier(identifier_type=<CompoundIdentifierType.SMILES: 2>, value='O=C([O-])Cc1ccccc1', details=None)], [CompoundIdentifier(identifier_type=<CompoundIdentifierType.SMILES: 2>, value='CCCCCCOC(C)=O', details=None)], [CompoundIdentifier(identifier_type=<CompoundIdentifierType.SMILES: 2>, value='CCCCCCCC(=O)[O-]', details=None)]])
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='glycol' details=None: Not Found
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='carvon' details=None: Not Found
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='dodecanoicacidmethylester' details=None: Not Found
# ERROR:pura.resolvers:Not sufficient agreement for identifiers=[CompoundIdentifier(identifier_type=<CompoundIdentifierType.NAME: 6>, value='dodecanoicacidmethylester', details=None)] amount=None mass=None volume=None (outputs: [[CompoundIdentifier(identifier_type=<CompoundIdentifierType.SMILES: 2>, value='CC=C(C)C(=O)OC', details=None)], []])
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='decanoicacidmethylester' details=None: Not Found
# ERROR:pura.resolvers:Not sufficient agreement for identifiers=[CompoundIdentifier(identifier_type=<CompoundIdentifierType.NAME: 6>, value='decanoicacidmethylester', details=None)] amount=None mass=None volume=None (outputs: [[CompoundIdentifier(identifier_type=<CompoundIdentifierType.SMILES: 2>, value='CCCCCCC=CCCCCCCCCCC(=O)OC', details=None)], []])
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='n,n-diethyl-benzeneamine' details=None: Not Found
# ERROR:pura.resolvers:Not sufficient agreement for identifiers=[CompoundIdentifier(identifier_type=<CompoundIdentifierType.NAME: 6>, value='n,n-diethyl-benzeneamine', details=None)] amount=None mass=None volume=None (outputs: [[]])
# ERROR:pura.resolvers:Not sufficient agreement for identifiers=[CompoundIdentifier(identifier_type=<CompoundIdentifierType.NAME: 6>, value='n-butylacetate', details=None)] amount=None mass=None volume=None (outputs: [[CompoundIdentifier(identifier_type=<CompoundIdentifierType.SMILES: 2>, value='CCCCOC(C)=O', details=None)], [CompoundIdentifier(identifier_type=<CompoundIdentifierType.SMILES: 2>, value='CCCCCC(=O)[O-]', details=None)]])
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='thp' details=None: Not Found
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='decanedioicaciddibutylester' details=None: Not Found
# ERROR:pura.resolvers:Not sufficient agreement for identifiers=[CompoundIdentifier(identifier_type=<CompoundIdentifierType.NAME: 6>, value='thp', details=None)] amount=None mass=None volume=None (outputs: [[CompoundIdentifier(identifier_type=<CompoundIdentifierType.SMILES: 2>, value='Cc1cn([C@H]2C[C@H](OP(=O)(O)O)[C@@H](COP(=O)(O)O)O2)c(=O)[nH]c1=O', details=None)]])
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='2-hydroxy-benzoicacidmethylester' details=None: Not Found
# ERROR:pura.resolvers:Not sufficient agreement for identifiers=[CompoundIdentifier(identifier_type=<CompoundIdentifierType.NAME: 6>, value='decanedioicaciddibutylester', details=None)] amount=None mass=None volume=None (outputs: [[]])
# ERROR:pura.resolvers:Not sufficient agreement for identifiers=[CompoundIdentifier(identifier_type=<CompoundIdentifierType.NAME: 6>, value='2-hydroxy-benzoicacidmethylester', details=None)] amount=None mass=None volume=None (outputs: [[]])
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='cs2' details=None: Not Found
# ERROR:pura.resolvers:Not sufficient agreement for identifiers=[CompoundIdentifier(identifier_type=<CompoundIdentifierType.NAME: 6>, value='cs2', details=None)] amount=None mass=None volume=None (outputs: [[CompoundIdentifier(identifier_type=<CompoundIdentifierType.SMILES: 2>, value='S=C=S', details=None)]])
# Batch 7 Progress: 100%|██████████| 100/100 [00:11<00:00,  8.38it/s]
# Batch:  80%|████████  | 8/10 [01:45<00:24, 12.50s/it]ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value="hunig's base" details=None: Not Found
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='pocl3' details=None: Not Found
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='d4' details=None: Not Found
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='h2o' details=None: Not Found
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='pcl3' details=None: Not Found
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='tes' details=None: Not Found
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='tfa' details=None: Not Found
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='mchm' details=None: Not Found
# ERROR:pura.resolvers:Not sufficient agreement for identifiers=[CompoundIdentifier(identifier_type=<CompoundIdentifierType.NAME: 6>, value='pocl3', details=None)] amount=None mass=None volume=None (outputs: [[CompoundIdentifier(identifier_type=<CompoundIdentifierType.SMILES: 2>, value='O=P(Cl)(Cl)Cl', details=None)], []])
# ERROR:pura.resolvers:Not sufficient agreement for identifiers=[CompoundIdentifier(identifier_type=<CompoundIdentifierType.NAME: 6>, value="hunig's base", details=None)] amount=None mass=None volume=None (outputs: [[CompoundIdentifier(identifier_type=<CompoundIdentifierType.SMILES: 2>, value='CCN(C(C)C)C(C)C', details=None)], []])
# ERROR:pura.resolvers:Not sufficient agreement for identifiers=[CompoundIdentifier(identifier_type=<CompoundIdentifierType.NAME: 6>, value='d4', details=None)] amount=None mass=None volume=None (outputs: [[CompoundIdentifier(identifier_type=<CompoundIdentifierType.SMILES: 2>, value='C[Si]1(C)O[Si](C)(C)O[Si](C)(C)O[Si](C)(C)O1', details=None)], []])
# ERROR:pura.resolvers:Not sufficient agreement for identifiers=[CompoundIdentifier(identifier_type=<CompoundIdentifierType.NAME: 6>, value='mchm', details=None)] amount=None mass=None volume=None (outputs: [[CompoundIdentifier(identifier_type=<CompoundIdentifierType.SMILES: 2>, value='CC1CCC(CO)CC1', details=None)], []])
# ERROR:pura.resolvers:Not sufficient agreement for identifiers=[CompoundIdentifier(identifier_type=<CompoundIdentifierType.NAME: 6>, value='tes', details=None)] amount=None mass=None volume=None (outputs: [[CompoundIdentifier(identifier_type=<CompoundIdentifierType.SMILES: 2>, value='O=S(=O)(O)CCNC(CO)(CO)CO', details=None)], [CompoundIdentifier(identifier_type=<CompoundIdentifierType.SMILES: 2>, value='C[C@]12CC[C@H]3[C@@H](CCC4=CC(=O)CC[C@@]43C)[C@@H]1CC[C@@H]2O', details=None)]])
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='d-limonene' details=None: Not Found
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='tfaa' details=None: Not Found
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='nnm' details=None: Not Found
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='dbu' details=None: Not Found
# ERROR:pura.resolvers:Not sufficient agreement for identifiers=[CompoundIdentifier(identifier_type=<CompoundIdentifierType.NAME: 6>, value='nnm', details=None)] amount=None mass=None volume=None (outputs: [[CompoundIdentifier(identifier_type=<CompoundIdentifierType.SMILES: 2>, value='CC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCCC(C)CCOP(=O)(O)O', details=None)], []])
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='thf' details=None: Not Found
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='formicacidpentylester' details=None: Not Found
# ERROR:pura.resolvers:Not sufficient agreement for identifiers=[CompoundIdentifier(identifier_type=<CompoundIdentifierType.NAME: 6>, value='formicacidpentylester', details=None)] amount=None mass=None volume=None (outputs: [[CompoundIdentifier(identifier_type=<CompoundIdentifierType.SMILES: 2>, value='CCCCCCCCC=CCCCCCCCC(=O)OCCCCCCCCCCCC', details=None)], []])
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='nmp' details=None: Not Found
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='m2' details=None: Not Found
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='ccl4' details=None: Not Found
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='cfcl3' details=None: Not Found
# ERROR:pura.resolvers:Not sufficient agreement for identifiers=[CompoundIdentifier(identifier_type=<CompoundIdentifierType.NAME: 6>, value='m2', details=None)] amount=None mass=None volume=None (outputs: [[], [CompoundIdentifier(identifier_type=<CompoundIdentifierType.SMILES: 2>, value='C=CC(C)(O)C(=O)Nc1cc(Cl)cc(Cl)c1', details=None)]])
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='chbr3' details=None: Not Found
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='dicyclopentadiene' details=None: Not Found
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='chcl3' details=None: Not Found
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='d5' details=None: Not Found
# ERROR:pura.resolvers:Not sufficient agreement for identifiers=[CompoundIdentifier(identifier_type=<CompoundIdentifierType.NAME: 6>, value='chbr3', details=None)] amount=None mass=None volume=None (outputs: [[CompoundIdentifier(identifier_type=<CompoundIdentifierType.SMILES: 2>, value='BrC(Br)Br', details=None)]])
# ERROR:pura.resolvers:Not sufficient agreement for identifiers=[CompoundIdentifier(identifier_type=<CompoundIdentifierType.NAME: 6>, value='n-propylacetate', details=None)] amount=None mass=None volume=None (outputs: [[CompoundIdentifier(identifier_type=<CompoundIdentifierType.SMILES: 2>, value='CCCOC(C)=O', details=None)], [CompoundIdentifier(identifier_type=<CompoundIdentifierType.SMILES: 2>, value='CCCCC(=O)[O-]', details=None)]])
# ERROR:pura.resolvers:Not sufficient agreement for identifiers=[CompoundIdentifier(identifier_type=<CompoundIdentifierType.NAME: 6>, value='dicyclopentadiene', details=None)] amount=None mass=None volume=None (outputs: [[CompoundIdentifier(identifier_type=<CompoundIdentifierType.SMILES: 2>, value='C1=CC2C3C=CC(C3)C2C1', details=None)]])
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='mdm' details=None: Not Found
# ERROR:pura.resolvers:Not sufficient agreement for identifiers=[CompoundIdentifier(identifier_type=<CompoundIdentifierType.NAME: 6>, value='d5', details=None)] amount=None mass=None volume=None (outputs: [[]])
# ERROR:pura.resolvers:Not sufficient agreement for identifiers=[CompoundIdentifier(identifier_type=<CompoundIdentifierType.NAME: 6>, value='chcl3', details=None)] amount=None mass=None volume=None (outputs: [[CompoundIdentifier(identifier_type=<CompoundIdentifierType.SMILES: 2>, value='ClC(Cl)Cl', details=None)]])
# ERROR:pura.resolvers:Not sufficient agreement for identifiers=[CompoundIdentifier(identifier_type=<CompoundIdentifierType.NAME: 6>, value='n-propylformate', details=None)] amount=None mass=None volume=None (outputs: [[CompoundIdentifier(identifier_type=<CompoundIdentifierType.SMILES: 2>, value='CCCOC=O', details=None)], [CompoundIdentifier(identifier_type=<CompoundIdentifierType.SMILES: 2>, value='CCCC(=O)[O-]', details=None)]])
# ERROR:pura.resolvers:Not sufficient agreement for identifiers=[CompoundIdentifier(identifier_type=<CompoundIdentifierType.NAME: 6>, value='mdm', details=None)] amount=None mass=None volume=None (outputs: [[CompoundIdentifier(identifier_type=<CompoundIdentifierType.SMILES: 2>, value='CO[C@H]1O[C@H](CO)[C@@H](O)[C@H](O[C@H]2O[C@H](CO)[C@@H](O)[C@H](O)[C@@H]2O)[C@@H]1O', details=None)]])
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='md2m' details=None: Not Found
# ERROR:pura.resolvers:Not sufficient agreement for identifiers=[CompoundIdentifier(identifier_type=<CompoundIdentifierType.NAME: 6>, value='md2m', details=None)] amount=None mass=None volume=None (outputs: [[]])
# Batch 8 Progress: 100%|██████████| 100/100 [00:13<00:00,  7.24it/s]
# Batch:  90%|█████████ | 9/10 [01:59<00:12, 12.91s/it]ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='thfa' details=None: Not Found
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='etbe' details=None: Not Found
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='tame' details=None: Not Found
# ERROR:pura.resolvers:Not sufficient agreement for identifiers=[CompoundIdentifier(identifier_type=<CompoundIdentifierType.NAME: 6>, value='tame', details=None)] amount=None mass=None volume=None (outputs: [[CompoundIdentifier(identifier_type=<CompoundIdentifierType.SMILES: 2>, value='COC(=O)C(CCCN=C(N)N)NS(=O)(=O)c1ccc(C)cc1', details=None)], [CompoundIdentifier(identifier_type=<CompoundIdentifierType.SMILES: 2>, value='CCC(C)(C)OC', details=None)]])
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='cpme' details=None: Not Found
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='dihydrolevoglucosenone' details=None: Not Found
# ERROR:pura.resolvers:Not sufficient agreement for identifiers=[CompoundIdentifier(identifier_type=<CompoundIdentifierType.NAME: 6>, value='dihydrolevoglucosenone', details=None)] amount=None mass=None volume=None (outputs: [[CompoundIdentifier(identifier_type=<CompoundIdentifierType.SMILES: 2>, value='O=C1CCC2COC1O2', details=None)], []])
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='diispropylethylamine' details=None: Not Found
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='mbk' details=None: Not Found
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='tmthf' details=None: Not Found
# ERROR:pura.resolvers:Not sufficient agreement for identifiers=[CompoundIdentifier(identifier_type=<CompoundIdentifierType.NAME: 6>, value='diispropylethylamine', details=None)] amount=None mass=None volume=None (outputs: [[]])
# ERROR:pura.resolvers:Not sufficient agreement for identifiers=[CompoundIdentifier(identifier_type=<CompoundIdentifierType.NAME: 6>, value='tmthf', details=None)] amount=None mass=None volume=None (outputs: [[]])
# ERROR:pura.resolvers:<pura.services.opsin.Opsin object at 0x145a96f20>, identifier_type=<CompoundIdentifierType.NAME: 6> value='gvl' details=None: Not Found
# ERROR:pura.resolvers:Not sufficient agreement for identifiers=[CompoundIdentifier(identifier_type=<CompoundIdentifierType.NAME: 6>, value='mbk', details=None)] amount=None mass=None volume=None (outputs: [[CompoundIdentifier(identifier_type=<CompoundIdentifierType.SMILES: 2>, value='CN1C2CCC1CC(OC(=O)C(CO)c1ccccc1)C2.CN1C2CCC1CC(OC(=O)C(CO)c1ccccc1)C2.O=S(=O)(O)O', details=None)]])
# ERROR:pura.resolvers:Not sufficient agreement for identifiers=[CompoundIdentifier(identifier_type=<CompoundIdentifierType.NAME: 6>, value='gvl', details=None)] amount=None mass=None volume=None (outputs: [[]])
# Batch 9 Progress: 100%|██████████| 15/15 [00:09<00:00,  1.60it/s]
# Batch: 100%|██████████| 10/10 [02:09<00:00, 12.91s/it]

# %%
names_dict = dict(names_pura)

# %%
names_dict
# Out:
# {'1-iodopentane': ['CCCCCI'],
#  '1,4-cyclohexadiene': ['C1=CCC=CC1'],
#  '1,4-dimethylbenzene': ['Cc1ccc(C)cc1'],
#  '1-chloro-2-methylbenzene': ['Cc1ccccc1Cl'],
#  '2-aminoethanol': ['NCCO'],
#  '1-bromoheptane': ['CCCCCCCBr'],
#  '1,4-dibromobenzene': ['Brc1ccc(Br)cc1'],
#  '1-bromonaphthalene': ['Brc1cccc2ccccc12'],
#  '1,4-dichlorobutane': ['ClCCCCCl'],
#  '1-dodecanol': ['CCCCCCCCCCCCO'],
#  '1,3-dichlorobenzene': ['Clc1cccc(Cl)c1'],
#  '1,1-diethoxymethane': ['CCOCOCC'],
#  '1,5-dichloropentane': ['ClCCCCCCl'],
#  '1-phenyl-1-propanone': ['CCC(=O)c1ccccc1'],
#  '1-methoxy-3-methylbenzene': ['COc1cccc(C)c1'],
#  '1,1,2-trichloroethane': ['ClCC(Cl)Cl'],
#  '1,3-dichloropropane': ['ClCCCCl'],
#  '1-ethyl-4-methylbenzene': ['CCc1ccc(C)cc1'],
#  '1-chloro-3-methylbutane': ['CC(C)CCCl'],
#  '1,2,3,4-tetrachlorobenzene': ['Clc1ccc(Cl)c(Cl)c1Cl'],
#  '1,3,5-trimethylbenzene': ['Cc1cc(C)cc(C)c1'],
#  '1-bromo-2-methylpropane': ['CC(C)CBr'],
#  '1,1,1-trichloroethane': ['CC(Cl)(Cl)Cl'],
#  '1-chloronaphthalene': ['Clc1cccc2ccccc12'],
#  '1-methoxy-4-methylbenzene': ['COc1ccc(C)cc1'],
#  '1-chloro-2,3-epoxypropane': ['ClCC1CO1'],
#  '1-bromopentane': ['CCCCCBr'],
#  '1,2-dichloropropane': ['CC(Cl)CCl'],
#  '1,2-diphenylethane': ['c1ccc(CCc2ccccc2)cc1'],
#  '1,3-dibromobenzene': ['Brc1cccc(Br)c1'],
#  '2-bromobutane': ['CCC(C)Br'],
#  '1,4-dibromobutane': ['BrCCCCBr'],
#  '1-octene': ['C=CCCCCCC'],
#  '1-chlorobutane': ['CCCCCl'],
#  '(z)-3-hexene': ['CC/C=C\\CC'],
#  '1,3-difluorobenzene': ['Fc1cccc(F)c1'],
#  '1,1,2,2-tetrabromoethane': ['BrC(Br)C(Br)Br'],
#  '1-iodohexane': ['CCCCCCI'],
#  '1,2-dichlorobenzene': ['Clc1ccccc1Cl'],
#  '1-bromohexane': ['CCCCCCBr'],
#  '2-butanol': ['CCC(C)O'],
#  '1,3-cyclohexadiene': ['C1=CCCC=C1'],
#  '(2e,4e)-2,4-hexadiene': ['C/C=C/C=C/C'],
#  '1,4-difluorobenzene': ['Fc1ccc(F)cc1'],
#  '(e)-2-butenenitrile': ['C/C=C/C#N'],
#  '1,3-dimethyltetrahydropyrimidin-2(1h)-one': ['CN1CCCN(C)C1=O'],
#  '1-bromododecane': ['CCCCCCCCCCCCBr'],
#  '1-bromobutane': ['CCCCBr'],
#  '1,1-dichloroethane': ['CC(Cl)Cl'],
#  '1,1,2-trichloro-1,2,2-trifluoroethane': ['FC(F)(Cl)C(F)(Cl)Cl'],
#  '1-chloro-2-methylpropane': ['CC(C)CCl'],
#  '1,2-diaminoethane': ['NCCN'],
#  '2-(2-aminoethylamino)ethanol': ['NCCNCCO'],
#  '1-hexanethiol': ['CCCCCCS'],
#  '1-bromo-3-methylbutane': ['CC(C)CCBr'],
#  '1-nitropropane': ['CCC[N+](=O)[O-]'],
#  '2-chloro-2-methylpropane': ['CC(C)(C)Cl'],
#  '1-methoxy-2-methylbenzene': ['COc1ccccc1C'],
#  '1,2,4-trichlorobenzene': ['Clc1ccc(Cl)c(Cl)c1'],
#  '1-iodopropane': ['CCCI'],
#  '1,2,3-trichloropropane': ['ClCC(Cl)CCl'],
#  '(1z,5z)-cycloocta-1,5-diene': ['C1=C\\CC/C=C\\CC/1'],
#  '1,3-dioxolan-2-one': ['O=C1OCCO1'],
#  '1,2-difluorobenzene': ['Fc1ccccc1F'],
#  '1,4-dichlorobenzene': ['Clc1ccc(Cl)cc1'],
#  '1-chloropentane': ['CCCCCCl'],
#  '1-bromo-2-chloroethane': ['ClCCBr'],
#  '1-chlorooctane': ['CCCCCCCCCl'],
#  '1-pentanethiol': ['CCCCCS'],
#  '1-hexene': ['C=CCCCC'],
#  '1,2-dibromoethane': ['BrCCBr'],
#  '(e)-1,3-pentadiene': ['C=C/C=C/C'],
#  '1,2,3-tribromopropane': ['BrCC(Br)CBr'],
#  '1-iodobutane': ['CCCCI'],
#  '1-methylnaphthalene': ['Cc1cccc2ccccc12'],
#  '1,1-dichloroethene': ['C=C(Cl)Cl'],
#  '1,2-dimethylbenzene': ['Cc1ccccc1C'],
#  '2-chloroaniline': ['Nc1ccccc1Cl'],
#  '1-chloropropane': ['CCCCl'],
#  '2-bromopropane': ['CC(C)Br'],
#  '1,4-butanediol': ['OCCCCO'],
#  '1-chlorohexane': ['CCCCCCCl'],
#  '1,1,1-trichlorotrifluoroethane': ['FC(F)(F)C(Cl)(Cl)Cl'],
#  '1,2-dichloroethane': ['ClCCCl'],
#  '1-pentene': ['C=CCCC'],
#  '1,3-dimethylbenzene': ['Cc1cccc(C)c1'],
#  '1,2-propanediol': ['CC(O)CO'],
#  '(trichloromethyl)benzene': ['ClC(Cl)(Cl)c1ccccc1'],
#  '1,1-diethoxyethane': ['CCOC(C)OCC'],
#  '1,2-dimethoxyethane': ['COCCOC'],
#  '1-bromooctane': ['CCCCCCCCBr'],
#  '1,3,3-trimethyl-2-oxabicyclo[2.2.2]octane': ['CC12CCC(CC1)C(C)(C)O2'],
#  '(dichloromethyl)benzene': ['ClC(Cl)c1ccccc1'],
#  '1-bromopropane': ['CCCBr'],
#  '1,2,3,4-tetramethylbenzene': ['Cc1ccc(C)c(C)c1C'],
#  '2-butoxyethanol': ['CCCCOCCO'],
#  '1,1,2,2-tetrachloroethane': ['ClC(Cl)C(Cl)Cl'],
#  '1,2-dimethoxybenzene': ['COc1ccccc1OC'],
#  '2-butanone': ['CCC(C)=O'],
#  '1,2,3-propanetriol': ['OCC(O)CO'],
#  '2,4-dimethyl-3-pentanone': ['CC(C)C(=O)C(C)C'],
#  '2-pentanone': ['CCCC(C)=O'],
#  '2-methyltetrahydrofuran': ['CC1CCCO1'],
#  '4-chlorotoluene': ['Cc1ccc(Cl)cc1'],
#  '2-nitropropane': ['CC(C)[N+](=O)[O-]'],
#  '2-methylpropylamine': ['CC(C)CN'],
#  '3-pentanone': ['CCC(=O)CC'],
#  '2-propen-1-amine': ['C=CCN'],
#  '2-methyl-1-butene': ['C=C(C)CC'],
#  '3-bromopropene': ['C=CCBr'],
#  '2,4-dimethylpentane': ['CC(C)CC(C)C'],
#  '3-methyl-1-butanol': ['CC(C)CCO'],
#  '3-bromopentane': ['CCC(Br)CC'],
#  '2-methylpropanoic acid': ['CC(C)C(=O)O'],
#  '3-chloroaniline': ['Nc1cccc(Cl)c1'],
#  '2-methoxyethanol': ['COCCO'],
#  '3-heptanone': ['CCCCC(=O)CC'],
#  '2,2-dichloropropane': ['CC(C)(Cl)Cl'],
#  '4-methyl-2-pentanone': ['CC(=O)CC(C)C'],
#  '2-methylaniline': ['Cc1ccccc1N'],
#  '2-methyl-2-propanamine': ['CC(C)(C)N'],
#  '2-heptanone': ['CCCCCC(C)=O'],
#  '2-propanone': ['CC(C)=O'],
#  '2-nitrotoluene': ['Cc1ccccc1[N+](=O)[O-]'],
#  '4-octanol': ['CCCCC(O)CCC'],
#  '3-bromopyridine': ['Brc1cccnc1'],
#  '4-methylpentanenitrile': ['CC(C)CCC#N'],
#  '2-octanol': ['CCCCCCC(C)O'],
#  '3-methylaniline': ['Cc1cccc(N)c1'],
#  '2,3-dimethyl-1,3-butadiene': ['C=C(C)C(=C)C'],
#  '2-methylpropyl acetate': ['CC(=O)OCC(C)C'],
#  '2-methyl-3-heptanol': ['CCCCC(O)C(C)C'],
#  '2,6-dimethylpyridine': ['Cc1cccc(C)n1'],
#  '4-methylaniline': ['Cc1ccc(N)cc1'],
#  '3-bromoaniline': ['Nc1cccc(Br)c1'],
#  '2-methoxyaniline': ['COc1ccccc1N'],
#  '2-methylpentane': ['CCCC(C)C'],
#  '3-isothiocyanatopropene': ['C=CCN=C=S'],
#  '2-methyl-2-propanethiol': ['CC(C)(C)S'],
#  '4-methyl-1,3-pentadiene': ['C=CC=C(C)C'],
#  '2,4,6-trimethyl-1,3,5-trioxane': ['CC1OC(C)OC(C)O1'],
#  '3-methylhexane': ['CCCC(C)CC'],
#  '2-methylpropylbenzene': ['CC(C)Cc1ccccc1'],
#  '4-ethylpyridine': ['CCc1ccncc1'],
#  '2-methylbenzonitrile': ['Cc1ccccc1C#N'],
#  '4-fluorotoluene': ['Cc1ccc(F)cc1'],
#  '2,4-pentanedione': ['CC(=O)CC(C)=O'],
#  '2,4-dimethylpyridine': ['Cc1ccnc(C)c1'],
#  '2-phenylethanol': ['OCCc1ccccc1'],
#  '3-heptanol': ['CCCCC(O)CC'],
#  '2,6-dimethyl-4-heptanone': ['CC(C)CC(=O)CC(C)C'],
#  '2,4-dimethylaniline': ['Cc1ccc(N)c(C)c1'],
#  '3,3-dimethyl-2-butanone': ['CC(=O)C(C)(C)C'],
#  '2,3-dimethylpentane': ['CCC(C)C(C)C'],
#  '3,3-dimethylpentane': ['CCC(C)(C)CC'],
#  '3-ethylpentane': ['CCC(CC)CC'],
#  '2-methyl-2-phenylpropane': ['CC(C)(C)c1ccccc1'],
#  '2-methoxy-2-methylpropane': ['COC(C)(C)C'],
#  '2-propen-1-ol': ['C=CCO'],
#  '4-methoxyaniline': ['COc1ccc(N)cc1'],
#  '2-ethoxyethanol': ['CCOCCO'],
#  '4-heptanol': ['CCCC(O)CCC'],
#  '2-methylpropyl formate': ['CC(C)COC=O'],
#  '3-octanol': ['CCCCCC(O)CC'],
#  '3-chlorotoluene': ['Cc1cccc(Cl)c1'],
#  '2,2,4-trimethylpentane': ['CC(C)CC(C)(C)C'],
#  '2-propenenitrile': ['C=CC#N'],
#  '3,6,9-trioxaundecane': ['CCOCCOCCOCC'],
#  '2-methylhexane': ['CCCCC(C)C'],
#  '2-octanone': ['CCCCCCC(C)=O'],
#  '2-cyanopyridine': ['N#Cc1ccccn1'],
#  '2,2-dimethylpentane': ['CCCC(C)(C)C'],
#  '4-methyl-2-oxo-1,3-dioxolane': ['CC1COC(=O)O1'],
#  '3-methyl-2-butanone': ['CC(=O)C(C)C'],
#  '2-methyl-2-butanol': ['CCC(C)(C)O'],
#  '4-nitroanisole': ['COc1ccc([N+](=O)[O-])cc1'],
#  '3,4-dimethylpyridine': ['Cc1ccncc1C'],
#  '4-methyl-3-heptanol': ['CCCC(C)C(O)CC'],
#  '3-chloropropene': ['C=CCCl'],
#  '3-methylbutyl acetate': ['CC(=O)OCCC(C)C'],
#  '2-methyl-1-propanol': ['CC(C)CO'],
#  '2,4,6-trimethylpyridine': ['Cc1cc(C)nc(C)c1'],
#  '3-methylbutanoic acid': ['CC(C)CC(=O)O'],
#  '4-methylpyridine': ['Cc1ccncc1'],
#  '2,3,4,5,6-pentafluorotoluene': ['Cc1c(F)c(F)c(F)c(F)c1F'],
#  '2,2,3-trimethylbutane': ['CC(C)C(C)(C)C'],
#  '2,2-dimethylpropane': ['CC(C)(C)C'],
#  '2-methyl-1-heptanol': ['CCCCCC(C)CO'],
#  '4-heptanone': ['CCCC(=O)CCC'],
#  '2-chlorobutane': ['CCC(C)Cl'],
#  '2-iodopropane': ['CC(C)I'],
#  '3-methylphenol': ['Cc1cccc(O)c1'],
#  '4-methyl-3-penten-2-one': ['CC(=O)C=C(C)C'],
#  '2-methyl-2-propanol': ['CC(C)(C)O'],
#  '2-phenylacetonitrile': ['N#CCc1ccccc1'],
#  '3-methylpyridine': ['Cc1cccnc1'],
#  '2-undecanone': ['CCCCCCCCCC(C)=O'],
#  '2,2-dimethylbutane': ['CCC(C)(C)C'],
#  '2-hexanone': ['CCCCC(C)=O'],
#  '2-nitroanisole': ['COc1ccccc1[N+](=O)[O-]'],
#  'cyclohexene': ['C1=CCCCC1'],
#  'butanethiol': ['CCCCS'],
#  'dipropylamine': ['CCCNCCC'],
#  'diethylamine': ['CCNCC'],
#  'dibromomethane': ['BrCBr'],
#  'diethyl oxalate': ['CCOC(=O)C(=O)OCC'],
#  'diisopropylamine': ['CC(C)NC(C)C'],
#  'bis(2-methoxyethyl) ether': ['COCCOCCOC'],
#  'diphenyl ether': ['c1ccc(Oc2ccccc2)cc1'],
#  'cis-decalin': ['C1CC[C@H]2CCCC[C@H]2C1'],
#  'diethyl carbonate': ['CCOC(=O)OCC'],
#  'acetonitrile': ['CC#N'],
#  'butanol': ['CCCCO'],
#  'butanoic acid': ['CCCC(=O)O'],
#  'decane': ['CCCCCCCCCC'],
#  'diphenylmethane': ['c1ccc(Cc2ccccc2)cc1'],
#  'diisopropyl sulfide': ['CC(C)SC(C)C'],
#  'acetophenone': ['CC(=O)c1ccccc1'],
#  'dibenzyl ether': ['c1ccc(COCc2ccccc2)cc1'],
#  'chlorocyclohexane': ['ClC1CCCCC1'],
#  'dimethylcyanamide': ['CN(C)C#N'],
#  'benzene': ['c1ccccc1'],
#  'diethanolamine': ['OCCNCCO'],
#  'dimethyl sulfoxide': ['CS(C)=O'],
#  'diethyl propanedioate': ['CCOC(=O)CC(=O)OCC'],
#  'cis-1,2-dichloroethene': ['Cl/C=C\\Cl'],
#  'chlorobenzene': ['Clc1ccccc1'],
#  'di-n-butyl sulfide': ['CCCCSCCCC'],
#  'dibutyl phthalate': ['CCCCOC(=O)c1ccccc1C(=O)OCCCC'],
#  'acetaldoxime': ['CC=NO'],
#  'bromocyclohexane': ['BrC1CCCCC1'],
#  'cyclooctatetraene': ['C1=CC=CC=CC=C1'],
#  'diethylene glycol': ['OCCOCCO'],
#  'benzoyl chloride': ['O=C(Cl)c1ccccc1'],
#  'cumene': ['CC(C)c1ccccc1'],
#  'diisopropyl ether': ['CC(C)OC(C)C'],
#  'benzyl alcohol': ['OCc1ccccc1'],
#  'carbon disulfide': ['S=C=S'],
#  'butyl acetate': ['CCCCOC(C)=O'],
#  'dipropyl ether': ['CCCOCCC'],
#  'butylamine': ['CCCCN'],
#  'cyclohexanamine': ['NC1CCCCC1'],
#  'cyclohexanecarboxylic acid': ['O=C(O)C1CCCCC1'],
#  'diethyl disulfide': ['CCSSCC'],
#  'cyclohexyl acetate': ['CC(=O)OC1CCCCC1'],
#  'anthracene': ['c1ccc2cc3ccccc3cc2c1'],
#  'dimethyl sulfide': ['CSC'],
#  'cyclohexane': ['C1CCCCC1'],
#  'dipentyl ether': ['CCCCCOCCCCC'],
#  'dodecane': ['CCCCCCCCCCCC'],
#  'benzaldehyde': ['O=Cc1ccccc1'],
#  'decanol': ['CCCCCCCCCCO'],
#  'diethyl (2e)-2-butenedioate': ['CCOC(=O)/C=C/C(=O)OCC'],
#  'cycloheptatriene': ['C1=CC=CCC=C1'],
#  'ethanediol': ['CC(O)O'],
#  'dimethyl propanedioate': ['COC(=O)CC(=O)OC'],
#  'dioxane': ['C1COCCO1'],
#  'dibutyl decandioate': ['CCCCOC(=O)CCCCCCCCC(=O)OCCCC'],
#  'acetic anhydride': ['CC(=O)OC(C)=O'],
#  'bromoethane': ['CCBr'],
#  'diethyl (2z)-2-butenedioate': ['CCOC(=O)/C=C\\C(=O)OCC'],
#  'dimethoxymethane': ['COCOC'],
#  'benzyl chloride': ['ClCc1ccccc1'],
#  '5-nonanone': ['CCCCC(=O)CCCC'],
#  'benzonitrile': ['N#Cc1ccccc1'],
#  'bromotrichloromethane': ['ClC(Cl)(Cl)Br'],
#  'butanenitrile': ['CCCC#N'],
#  'd-carvone': [],
#  'bis(2-chloroethyl) ether': ['ClCCOCCCl'],
#  'butanal': ['CCCC=O'],
#  'ethanol': ['CCO'],
#  'dibutyl ether': ['CCCCOCCCC'],
#  'cyclooctane': ['C1CCCCCCC1'],
#  'diethyl sulfide': ['CCSCC'],
#  'diethyl butanedioate': ['CCOC(=O)CCC(=O)OCC'],
#  'acetic acid': ['CC(=O)O'],
#  'dibutylamine': ['CCCCNCCCC'],
#  'acenaphthene': ['c1cc2c3c(cccc3c1)CC2'],
#  'diiodomethane': ['ICI'],
#  'diethyl ether': ['CCOCC'],
#  '4,n,n-trimethylaniline': [],
#  'benzylamine': ['NCc1ccccc1'],
#  'dibenzofuran': ['c1ccc2c(c1)oc1ccccc12'],
#  'dimethyl disulfide': ['CSSC'],
#  'dichloromethane': ['ClCCl'],
#  'acetyl chloride': ['CC(=O)Cl'],
#  'cyclopentane': ['C1CCCC1'],
#  'benzyl acetate': ['CC(=O)OCc1ccccc1'],
#  'butoxybenzene': ['CCCCOc1ccccc1'],
#  'dimethyl sulfate': ['COS(=O)(=O)OC'],
#  'cyclopentanone': ['O=C1CCCC1'],
#  'biphenyl': ['c1ccc(-c2ccccc2)cc1'],
#  'bromobenzene': ['Brc1ccccc1'],
#  'cyclohexanol': ['OC1CCCCC1'],
#  'dimethyl carbonate': ['COC(=O)OC'],
#  'dimethyl phthalate': ['COC(=O)c1ccccc1C(=O)OC'],
#  'butane': ['CCCC'],
#  'cyclohexanone': ['O=C1CCCCC1'],
#  'ethanethiol': ['CCS'],
#  'aniline': ['Nc1ccccc1'],
#  'furfural': ['O=Cc1ccco1'],
#  'ethyl salicylate': ['CCOC(=O)c1ccccc1O'],
#  'nitrobenzene': ['O=[N+]([O-])c1ccccc1'],
#  'methylbutane': ['CCCCC'],
#  'pentane': ['CCCCC'],
#  'ethylbenzene': ['CCc1ccccc1'],
#  'perfluoro-n-octane': ['FC(F)(F)C(F)(F)C(F)(F)C(F)(F)C(F)(F)C(F)(F)C(F)(F)C(F)(F)F'],
#  'methyl propanoate': ['CCC(=O)OC'],
#  "n,n,n',n'-tetramethylurea": [],
#  'octane': ['CCCCCCCC'],
#  'ethyl acetate': ['CCOC(C)=O'],
#  'methyl thiocyanate': ['CSC#N'],
#  'ethyl cyanoacetate': ['CCOC(=O)CC#N'],
#  'phenyl acetate': ['CC(=O)Oc1ccccc1'],
#  'methoxybenzene': ['COc1ccccc1'],
#  'fluorobenzene': ['Fc1ccccc1'],
#  'oxolan-2-one': ['O=C1CCCO1'],
#  'nitromethane': ['C[N+](=O)[O-]'],
#  'n-methylpyrrolidon': ['CN1CCCC1=O'],
#  'ethyl hexanoate': ['CCCCCC(=O)OCC'],
#  'formic acid': ['O=CO'],
#  'hexafluorobenzene': ['Fc1c(F)c(F)c(F)c(F)c1F'],
#  'ethyl 3-oxobutanoate': ['CCOC(=O)CC(C)=O'],
#  'n-methylformamide': ['CNC=O'],
#  'n-methylaniline': ['CNc1ccccc1'],
#  'methyl octanoate': ['CCCCCCCC(=O)OC'],
#  'methyl pentanoate': ['CCCCC(=O)OC'],
#  'pentachloroethane': ['ClC(Cl)C(Cl)(Cl)Cl'],
#  'hexane': ['CCCCCC'],
#  'hexamethylphosphoramide': ['CN(C)P(=O)(N(C)C)N(C)C'],
#  'morpholine': ['C1COCCN1'],
#  'perfluoro(methylcyclohexane)': ['FC(F)(F)C1(F)C(F)(F)C(F)(F)C(F)(F)C(F)(F)C1(F)F'],
#  'n,n-dimethylcyclohexylamine': [],
#  'pentanoic acid': ['CCCCC(=O)O'],
#  'methyl benzoate': ['COC(=O)c1ccccc1'],
#  'methyl hexanoate': ['CCCCCC(=O)OC'],
#  'heptanal': ['CCCCCCC=O'],
#  'formamide': ['NC=O'],
#  'nonane': ['CCCCCCCCC'],
#  'methyl trichloroacetate': ['COC(=O)C(Cl)(Cl)Cl'],
#  'hexanenitrile': ['CCCCCC#N'],
#  'octylamine': ['CCCCCCCCN'],
#  'pentyl acetate': ['CCCCCOC(C)=O'],
#  'phenyl isothiocyanate': ['S=C=Nc1ccccc1'],
#  'methyl butanoate': ['CCCC(=O)OC'],
#  'pentyl formate': ['CCCCCOC=O'],
#  'heptanol': ['CCCCCCCO'],
#  'n,n-dimethylacetamide': [],
#  'phenylhydrazine': ['NNc1ccccc1'],
#  'nitric acid': ['O=[N+]([O-])O'],
#  'isoquinoline': ['c1ccc2cnccc2c1'],
#  'methylcyclohexane': ['CC1CCCCC1'],
#  'ethyl chloroacetate': ['CCOC(=O)CCl'],
#  'methyl acetate': ['COC(C)=O'],
#  'hexylamine': ['CCCCCCN'],
#  'ethyl 2-hydroxypropanoate': ['CCOC(=O)C(C)O'],
#  'methylcyclopentane': ['CC1CCCC1'],
#  'isoprene': ['C=CC(=C)C'],
#  'ethyl benzoate': ['CCOC(=O)c1ccccc1'],
#  'methyl 2-propenoate': ['C=CC(=O)OC'],
#  'isopropylamine': ['CC(C)N'],
#  'n,n-dimethylaniline': [],
#  'iodobenzene': ['Ic1ccccc1'],
#  'methylsulfanylbenzene': ['CSc1ccccc1'],
#  'iodomethane': ['CI'],
#  'pentanal': ['CCCCC=O'],
#  'ethyl formate': ['CCOC=O'],
#  'n-methylcyclohexylamine': ['CNC1CCCCC1'],
#  'hexyl acetate': ['CCCCCCOC(C)=O'],
#  'phenol': ['Oc1ccccc1'],
#  'ethyl propanoate': ['CCOC(=O)CC'],
#  'methyl 2-hydroxybenzoate': ['COC(=O)c1ccccc1O'],
#  'ethyl butanoate': ['CCCC(=O)OCC'],
#  'pentylamine': ['CCCCCN'],
#  'iodoethane': ['CCI'],
#  'oxane': ['C1CCOCC1'],
#  'octanol': ['CCCCCCCCO'],
#  'hexanol': ['CCCCCCO'],
#  'oxirane': ['C1CO1'],
#  'octanoic acid': ['CCCCCCCC(=O)O'],
#  'nonanol': ['CCCCCCCCCO'],
#  'naphthalene': ['c1ccc2ccccc2c1'],
#  'ethyl thiocyanate': ['CCSC#N'],
#  'hexanoic acid': ['CCCCCC(=O)O'],
#  'furan': ['c1ccoc1'],
#  'n-methylpiperidine': ['CN1CCCCC1'],
#  'heptane': ['CCCCCCC'],
#  'methyl formate': ['COC=O'],
#  'n,n-diethylaniline': [],
#  'pentanenitrile': ['CCCCC#N'],
#  'ethyl isothiocyanate': ['CCN=C=S'],
#  'ethoxybenzene': ['CCOc1ccccc1'],
#  'ethynylbenzene': ['C#Cc1ccccc1'],
#  'hexadecane': ['CCCCCCCCCCCCCCCC'],
#  'methyl decanoate': ['CCCCCCCCCC(=O)OC'],
#  'methyl dodecanoate': ['CCCCCCCCCCCC(=O)OC'],
#  'nitroethane': ['CC[N+](=O)[O-]'],
#  'n-methylacetamide': ['CNC(C)=O'],
#  'n,n-dimethylformamide': [],
#  'ethyl nitrate': ['CCO[N+](=O)[O-]'],
#  '(e)-1,2-dichloroethene': ['Cl/C=C/Cl'],
#  '(trifluoromethoxy)benzene': ['FC(F)(F)Oc1ccccc1'],
#  'trans-decalin': ['C1CC[C@H]2CCCC[C@@H]2C1'],
#  '1,1,1,3,3,3-hexafluoropropan-2-ol': ['OC(C(F)(F)F)C(F)(F)F'],
#  'butan-2-ol': ['CCC(C)O'],
#  'triacetin': ['CC(=O)OCC(COC(C)=O)OC(C)=O'],
#  'pyrrolidine': ['C1CCNC1'],
#  '2-methylpropan-1-ol': ['CC(C)CO'],
#  'propanenitrile': ['CCC#N'],
#  'propyl acetate': ['CCCOC(C)=O'],
#  'propanal': ['CCC=O'],
#  'tetranitromethane': ['O=[N+]([O-])C([N+](=O)[O-])([N+](=O)[O-])[N+](=O)[O-]'],
#  '1,3-dioxolane': ['C1COCO1'],
#  'salicylaldehyde': ['O=Cc1ccccc1O'],
#  'tetrachloroethene': ['ClC(Cl)=C(Cl)Cl'],
#  '4-methylcyclohexanemethanol': ['CC1CCC(CO)CC1'],
#  'propanedinitrile': ['N#CCC#N'],
#  '3-methylbutan-1-ol': ['CC(C)CCO'],
#  'trichloronitromethane': ['O=[N+]([O-])C(Cl)(Cl)Cl'],
#  '1,2-ethanediol': ['OCCO'],
#  'thiophene': ['c1ccsc1'],
#  '1,2,3,4,5-pentafluoro-6-(trifluoromethyl)benzene': ['Fc1c(F)c(F)c(C(F)(F)F)c(F)c1F'],
#  'sulfuryl chloride': ['O=S(=O)(Cl)Cl'],
#  'vinyl acetate': ['C=COC(C)=O'],
#  'trichloroethanenitrile': ['N#CC(Cl)(Cl)Cl'],
#  'phosphorus oxychloride': ['O=P(Cl)(Cl)Cl'],
#  'tetrahydronaphthalene': ['c1ccc2c(c1)CCCC2'],
#  'triphenylmethane': ['c1ccc(C(c2ccccc2)c2ccccc2)cc1'],
#  '2-methyl butanol': ['CCC(C)CO'],
#  'thionyl chloride': ['O=S(Cl)Cl'],
#  '2,2,2-trifluoroethanol': ['OCC(F)(F)F'],
#  '1-methyl-4-(prop-1-en-2-yl)cyclohex-1-ene': ['C=C(C)C1CC=C(C)CC1'],
#  'butyl cellosolve': [],
#  'benzyl benzoate': ['O=C(OCc1ccccc1)c1ccccc1'],
#  'propylamine': ['CCCN'],
#  '1,3,2-dioxathiolane-2-oxide': ['O=S1OCCO1'],
#  'pyrrole': ['c1cc[nH]c1'],
#  'propyl formate': ['CCCOC=O'],
#  '1,2-dimethoxypropane': ['COCC(C)OC'],
#  'triethyl phosphate': ['CCOP(=O)(OCC)OCC'],
#  '2,2-dimethyl-1,3-dioxolane': ['CC1(C)OCCO1'],
#  'trans-1,2-dichloroethene': ['Cl/C=C/Cl'],
#  '1,8-diazabicycloundec-7-ene': [],
#  'tribromomethane': ['BrC(Br)Br'],
#  '2-methoxy-1-[(1-methoxy-2-propanyl)oxy]propane': ['COCC(C)OCC(C)OC'],
#  '2,2-dimethoxypropane': ['COC(C)(C)OC'],
#  '2-ethoxyethyl acetate': ['CCOCCOC(C)=O'],
#  '2-methylpyridine': ['Cc1ccccn1'],
#  '2-ethylhexanol': ['CCCCC(CC)CO'],
#  'styrene': ['C=Cc1ccccc1'],
#  '3,5,5-trimethylcyclohex-2-enone': ['CC1=CC(=O)CC(C)(C)C1'],
#  'butyl carbitol': [],
#  'phosphorus trichloride': ['ClP(Cl)Cl'],
#  'tetramethylsilane': ['C[Si](C)(C)C'],
#  '1,3-dithiolane': ['C1CSCS1'],
#  'phenylisocyanate': ['O=C=Nc1ccccc1'],
#  'triethoxymethane': ['CCOC(OCC)OCC'],
#  'propane': ['CCC'],
#  'propene': ['C=CC'],
#  'butan-1-ol': ['CCCCO'],
#  'sulfolane': ['O=S1(=O)CCCC1'],
#  '(z)-1,2-dichloroethene': ['Cl/C=C\\Cl'],
#  'thiane': ['C1CCSCC1'],
#  '(2,2-dimethyl-1,3-dioxolan-4-yl)methanol': ['CC1(C)OCC(CO)O1'],
#  'propyl nitrate': ['CCCO[N+](=O)[O-]'],
#  'trichlorofluoromethane': ['FC(Cl)(Cl)Cl'],
#  'butoxytriglycol': [],
#  '1-methylazepan-2-one': ['CN1CCCCCC1=O'],
#  'trichloromethane': ['ClC(Cl)Cl'],
#  'benzotrifluoride': ['FC(F)(F)c1ccccc1'],
#  '2-methylcyclohexanone': ['CC1CCCCC1=O'],
#  '2,2,2-trifluoroacetic anhydride': ['O=C(OC(=O)C(F)(F)F)C(F)(F)F'],
#  'trimethyl phosphate': ['COP(=O)(OC)OC'],
#  'pyrazine': ['c1cnccn1'],
#  'trichloroethene': ['ClC=C(Cl)Cl'],
#  'water': ['O'],
#  'propylbenzene': ['CCCc1ccccc1'],
#  'propanoic acid': ['CCC(=O)O'],
#  'tricyclo[5.2.1.02,6]deca-3,8-diene': ['C1=CC2C3C=CC(C3)C2C1'],
#  'propanol': ['CCCO'],
#  'undecane': ['CCCCCCCCCCC'],
#  '2,2,4-trimethyl-1,3-pentanediol 1-isobutyrate': ['CC(C)C(=O)OCC(C)(C)C(O)C(C)C'],
#  '2-methylbutan-2-ol': ['CCC(C)(C)O'],
#  '2,2,2-trifluoroacetic acid': ['O=C(O)C(F)(F)F'],
#  'trifluoromethylbenzene': ['FC(F)(F)c1ccccc1'],
#  'piperidine': ['C1CCNCC1'],
#  '1,2-diacetoxypropane': ['CC(=O)OCC(C)OC(C)=O'],
#  'propyl propanoate': ['CCCOC(=O)CC'],
#  'toluene': ['Cc1ccccc1'],
#  'tributylamine': ['CCCCN(CCCC)CCCC'],
#  '4-hydroxy-4-methylpentan-2-one': ['CC(=O)CC(C)(C)O'],
#  'pyridine': ['c1ccncc1'],
#  'quinoline': ['c1ccc2ncccc2c1'],
#  'trifluoroacetic acid': ['O=C(O)C(F)(F)F'],
#  '1,4-dioxane': ['C1COCCO1'],
#  'butyl carbitol acetate': [],
#  'tetrachloromethane': ['ClC(Cl)(Cl)Cl'],
#  'triethylamine': ['CCN(CC)CC'],
#  'undecanol': ['CCCCCCCCCCCO'],
#  'tetrahydrofuran': ['C1CCOC1'],
#  'di-isopropylether': ['CC(C)OC(C)C'],
#  'methyl propionate': ['CCC(=O)OC'],
#  'tetraethylsulfamide': ['CCN(CC)S(=O)(=O)N(CC)CC'],
#  'tetraethylene glycol': ['OCCOCCOCCOCCO'],
#  'cyclopentyl methyl ether': ['COC1CCCC1'],
#  'methyl carbitol': ['COCCOCCO'],
#  'n-ethylaniline': ['CCNc1ccccc1'],
#  'n-hexane': ['CCCCCC'],
#  'tetrahydrothiophene 1-oxide': ['O=S1CCCC1'],
#  'n-methylmorpholine': ['CN1CCOCC1'],
#  'pentan-3-one': ['CCC(=O)CC'],
#  'octamethyltrisiloxane': ['C[Si](C)(C)O[Si](C)(C)O[Si](C)(C)C'],
#  '1-methoxypropan-2-ol': ['COCC(C)O'],
#  'tetrahydrothiophene': ['C1CCSC1'],
#  'diethyleneglycol diethyl ether': ['CCOCCOCCOCC'],
#  'iso-butyl acetate': ['CC(=O)OCC(C)C'],
#  'dibutyl succinate': ['CCCCOC(=O)CCC(=O)OCCCC'],
#  'hexamethyldisiloxane': ['C[Si](C)(C)O[Si](C)(C)C'],
#  'methyl isobutyl carbinol': ['CC(C)CC(C)O'],
#  'hexanedinitrile': ['N#CCCCCC#N'],
#  'dimethyl sulfite': ['COS(=O)OC'],
#  '1,3-dimethylimidazolidin-2-one': ['CN1CCN(C)C1=O'],
#  'tetramethoxymethane': ['COC(OC)(OC)OC'],
#  'n-propyl propionate': ['CCCOC(=O)CC'],
#  'dimethyl adipate': ['COC(=O)CCCCC(=O)OC'],
#  'chloroform': ['ClC(Cl)Cl'],
#  'trimethoxymethane': ['COC(OC)OC'],
#  '1-pentanol': ['CCCCCO'],
#  'n-octane': ['CCCCCCCC'],
#  'ethane-1,2-diyl diacetate': ['CC(=O)OCCOC(C)=O'],
#  'pyrimidine': ['c1cncnc1'],
#  'decamethylcyclopentasiloxane': ['C[Si]1(C)O[Si](C)(C)O[Si](C)(C)O[Si](C)(C)O[Si](C)(C)O1'],
#  'propylene glycol': ['CC(O)CO'],
#  'ethyl butyrate': ['CCCC(=O)OCC'],
#  'octamethylcyclotetrasiloxane': ['C[Si]1(C)O[Si](C)(C)O[Si](C)(C)O[Si](C)(C)O1'],
#  'mtbe': ['COC(C)(C)C'],
#  'isobutyric acid': ['CC(C)C(=O)O'],
#  '1,3-propanediol': ['OCCCO'],
#  'perfluorobenzene': ['Fc1c(F)c(F)c(F)c(F)c1F'],
#  'methyl butyrate': ['CCCC(=O)OC'],
#  'pyridazine': ['c1ccnnc1'],
#  'hmpa': ['CN(C)P(=O)(N(C)C)N(C)C'],
#  'n-ethyl-n-isopropylpropan-2-amine': ['CCN(C(C)C)C(C)C'],
#  'butyl cellosolve acetate': ['CCCCOCCOC(C)=O'],
#  'proprionitrile': [],
#  'hexyl carbitol': ['CCCCCCOCCOCCO'],
#  'dimethyl isosorbide': [],
#  '2-ethylhexylacetate': [],
#  'butyl formate': ['CCCCOC=O'],
#  'n-pentyl acetate': ['CCCCCOC(C)=O'],
#  'decamethyltetrasiloxane': ['C[Si](C)(C)O[Si](C)(C)O[Si](C)(C)O[Si](C)(C)C'],
#  'propan-1-ol': ['CCCO'],
#  'pentan-3-ol': ['CCC(O)CC'],
#  'isopentyl acetate': ['CC(=O)OCCC(C)C'],
#  'ethyl 3-ethoxypropionate': ['CCOCCC(=O)OCC'],
#  'triglyme': ['COCCOCCOCCOC'],
#  'pentan-2-ol': ['CCCC(C)O'],
#  'dihydrofuran-2(3h)-one': ['O=C1CCCO1'],
#  'butyric acid': ['CCCC(=O)O'],
#  'pentan-1-ol': ['CCCCCO'],
#  'triethylene glycol': ['OCCOCCOCCO'],
#  'propyl cellosolve': ['CCCOCCO'],
#  'dipropylene glycol dimethyl ether': ['COCC(C)OCC(C)OC'],
#  'iso-propyl acetate': ['CC(=O)OC(C)C'],
#  'n-pentane': ['CCCCC'],
#  'carbitol': ['CCOCCOCCO'],
#  'n-methylpyrrolidone': ['CN1CCCC1=O'],
#  'ethyl propionate': ['CCOC(=O)CC'],
#  'tpm glycol ether': [],
#  'pgda glycol ether': [],
#  'pnb glycol ether': [],
#  'dpm glycol ether': [],
#  'tpnb glycol ether': [],
#  'triethanolamine': ['OCCN(CCO)CCO'],
#  'dpnb glycol ether': [],
#  'ethylcyclohexane': ['CCC1CCCCC1'],
#  'n-pentyl propionate': ['CCCCCOC(=O)CC'],
#  'pentan-2-one': ['CCCC(C)=O'],
#  'butylbenzene': ['CCCCc1ccccc1'],
#  'n-butyl acetate': ['CCCCOC(C)=O'],
#  'p-xylene': ['Cc1ccc(C)cc1'],
#  'n-propyl acetate': ['CCCOC(C)=O'],
#  '2-propanol': ['CC(C)O'],
#  'butylene carbonate': ['O=C1OCCCCO1'],
#  'tmu': [],
#  'eph glycol ether': [],
#  'perfluorodecalin': ['FC1(F)C(F)(F)C(F)(F)C2(F)C(F)(F)C(F)(F)C(F)(F)C(F)(F)C2(F)C1(F)F'],
#  'pm glycol ether': [],
#  'hexan-2-one': ['CCCCC(C)=O'],
#  'pph glycol ether': [],
#  'propylene carbonate': ['CC1COC(=O)O1'],
#  'pma glycol ether': [],
#  '1,2,3-trimethoxy propane': ['COCC(COC)OC'],
#  'cyrene': [],
#  'dpma glycol ether': [],
#  'nep': [],
#  'dpnp glycol ether': [],
#  'ipa': [],
#  'pentamethyl phosphonic diamide': ['CN(C)P(C)(=O)N(C)C'],
#  'pnp glycol ether': [],
#  'acetone': ['CC(C)=O'],
#  'acetaldehydeoxime': ['CC=NO'],
#  'tert-butanol': ['CC(C)(C)O'],
#  'acetylchloride': ['CC(=O)Cl'],
#  '3-methyl-hexane': ['CCCC(C)CC'],
#  'isobutanol': ['CC(C)CO'],
#  't-butyl acetate': ['CC(=O)OC(C)(C)C'],
#  'm-difluorobenzene': ['Fc1cccc(F)c1'],
#  'furfuryl alcohol': ['OCc1ccco1'],
#  'dodecanol': ['CCCCCCCCCCCCO'],
#  '1-iodo-hexane': ['CCCCCCI'],
#  'isobutylbenzene': ['CC(C)Cc1ccccc1'],
#  'o-difluorobenzene': ['Fc1ccccc1F'],
#  'pyrido(2,3-b)pyrazine': ['c1cnc2nccnc2c1'],
#  'tert-amyl ethyl ether': ['CCOC(C)(C)CC'],
#  '4-methylanisole': ['COc1ccc(C)cc1'],
#  'p-cymene': ['Cc1ccc(C(C)C)cc1'],
#  '2,4,6-collidine': ['Cc1cc(C)nc(C)c1'],
#  '1-methoxy-2-nitrobenzene': ['COc1ccccc1[N+](=O)[O-]'],
#  'isopentanol': ['CC(C)CCO'],
#  'bis(2-chloroethyl)ether': ['ClCCOCCCl'],
#  'p-anisidine': ['COc1ccc(N)cc1'],
#  'butyronitrile': ['CCCC#N'],
#  'butanone': ['CCC(C)=O'],
#  '1,5-cyclooctadiene': ['C1=CCCC=CCC1'],
#  '2-amino-2-methylpropane': ['CC(C)(C)N'],
#  'trans,trans-2,4-hexadiene': ['C/C=C/C=C/C'],
#  'p-limonene': [],
#  'aceticacid-2-methylpropylester': ['CC(=O)OCC(C)C'],
#  '4-methylpentanitrile': [],
#  '(dichloromethyl)-benzene': ['ClC(Cl)c1ccccc1'],
#  'acetylacetone': ['CC(=O)CC(C)=O'],
#  '1,4-dibrombenzene': [],
#  '3-chlorobenzeneamine': ['Nc1cccc(Cl)c1'],
#  'octan-4-ol': ['CCCCC(O)CCC'],
#  'propiophenone': ['CCC(=O)c1ccccc1'],
#  'diethoxymethane': ['CCOCOCC'],
#  '1,1,1-trichloro-2,2,2-trifluoroethane': ['FC(F)(F)C(Cl)(Cl)Cl'],
#  '2-methyl-1-propanamine': ['CC(C)CN'],
#  'indane': ['c1ccc2c(c1)CCC2'],
#  'isobutylbromide': ['CC(C)CBr'],
#  '(chloromethyl)-benzene': ['ClCc1ccccc1'],
#  'p-nitroanisole': ['COc1ccc([N+](=O)[O-])cc1'],
#  'glycol diacetate': ['CC(=O)OCCOC(C)=O'],
#  '1,8-cineole': ['CC12CCC(CC1)C(C)(C)O2'],
#  'methyl-t-butylether': ['COC(C)(C)C'],
#  'p-difluorobenzene': ['Fc1ccc(F)cc1'],
#  '(1,1-dimethylethyl)benzene': ['CC(C)(C)c1ccccc1'],
#  '(chloromethyl)-oxirane': ['ClCC1CO1'],
#  'isopropyl acetate': ['CC(=O)OC(C)C'],
#  'cis-3-hexene': ['CC/C=C\\CC'],
#  'ethoxyethanol': ['CCOC(C)O'],
#  'paraldehyde': ['CC1OC(C)OC(C)O1'],
#  'dmtt(dazomet)': [],
#  'aceticacidphenylmethylester': [],
#  'aceticanhydride': ['CC(=O)OC(C)=O'],
#  'aceticacid': ['CC(=O)O'],
#  'isobutyricacid': ['CC(C)C(=O)O'],
#  'tert-butylthiol': ['CC(C)(C)S'],
#  '1,4-butadiol': [],
#  "1,1'-(1,2-ethanediyl)bis-benzene": ['c1ccc(CCc2ccccc2)cc1'],
#  'isovalericacid': ['CC(C)CC(=O)O'],
#  '2-(2-aminoethyl)aminoethanol': ['NCCNCCO'],
#  'dmpu': [],
#  'ethanolamine': ['NCCO'],
#  'diglyme': ['COCCOCCOC'],
#  'phenylacetonitrile': ['N#CCc1ccccc1'],
#  'methanol': ['CO'],
#  'benzoylchloride': ['O=C(Cl)c1ccccc1'],
#  'tetrahydro furfuryl alcohol': ['OCC1CCCO1'],
#  'ethyl lactate': ['CCOC(=O)C(C)O'],
#  'gamma-valerolactone': ['CC1CCC(=O)O1'],
#  'pentene': ['C=CCCC'],
#  'benzylalcohol': ['OCc1ccccc1'],
#  '(trichloromethyl)-benzene': ['ClC(Cl)(Cl)c1ccccc1'],
#  'ethyl tert-butyl ether': ['CCOC(C)(C)C'],
#  '3-methylanisole': ['COc1cccc(C)c1'],
#  'methyl oleate': ['CCCCCCCC/C=C\\CCCCCCCC(=O)OC'],
#  'glycerol': ['OCC(O)CO'],
#  'n,n,4-trimethylaniline': [],
#  '1,1-dichloroethylene': ['C=C(Cl)Cl'],
#  'propylenecarbonate': [],
#  '1-cis-2-trans-3-trimethylcyclopentane': [],
#  '3-picoline': ['Cc1cccnc1'],
#  'propyleneglycol': ['CC(O)CO'],
#  '1,5-dichloro-pentane': ['ClCCCCCCl'],
#  '3-hydroxytoluene': ['Cc1cccc(O)c1'],
#  'neopentane': ['CC(C)(C)C'],
#  'isoamylchloride': ['CC(C)CCCl'],
#  'tetramethyl tetrahydrofurane': ['CC1(C)CCOC1(C)C'],
#  '1-chloro-2-methyl-propane': ['CC(C)CCl'],
#  '1-trans-3-pentadiene': [],
#  '2-methyl-benzeneamine': ['Cc1ccccc1N'],
#  '1-chloro-4-methylbenzene': ['Cc1ccc(Cl)cc1'],
#  'octene': ['C=CCCCCCC'],
#  'isobutylformate': [],
#  'n-methylpentafluorobenzene': [],
#  'xylenes': [],
#  "1,1'-oxybis-2-ethoxy-ethane": [],
#  'isoamylacetate': ['CC(C)CCCC(=O)[O-]'],
#  'ethylpropionate': ['CCOC(=O)CC'],
#  '1-decanol': ['CCCCCCCCCCO'],
#  'dimethylsulfoxide': ['CS(C)=O'],
#  'methylthiocyanate': ['CSC#N'],
#  'diphenylether': ['c1ccc(Oc2ccccc2)cc1'],
#  'gamma-butyrolactone': ['O=C1CCCO1'],
#  'diethylether': ['CCOCC'],
#  '2,4,4-trimethyl-2-pentanethiol': ['CC(C)(C)CC(C)(C)S'],
#  'ethylthiocyanate': ['CCSC#N'],
#  '1-nonanol': ['CCCCCCCCCO'],
#  'n-nonane': ['CCCCCCCCC'],
#  'methyloctanoate': ['CCCCCCCC(=O)OC'],
#  'di-n-propylether': ['CCCOCCC'],
#  'methylpropionate': ['CCC(=O)OC'],
#  'diethylcarbonate': ['CCOC(=O)OCC'],
#  'diethylmalonate': ['CCC(CC)(C(=O)[O-])C(=O)[O-]'],
#  'dimethylcarbonate': ['COC(=O)OC'],
#  'ethylformate': ['CCOC=O'],
#  'n-hexadecane': ['CCCCCCCCCCCCCCCC'],
#  '1-butanol': ['CCCCO'],
#  'di-n-butylsulfide': ['CCCCSCCCC'],
#  'isopropylbenzene': ['CC(C)c1ccccc1'],
#  '1-octanol': ['CCCCCCCCO'],
#  '1-heptanol': ['CCCCCCCO'],
#  'ethylchloroacetate': ['CCOC(=O)CCl'],
#  'di-n-butylether': ['CCCCOCCCC'],
#  'dibenzylether': ['c1ccc(COCc2ccccc2)cc1'],
#  'cyclohexylamine': ['NC1CCCCC1'],
#  'diisopropylether': ['CC(C)OC(C)C'],
#  'methylacrylate': ['C=CC(=O)OC'],
#  '1-butylamine': ['CCCCN'],
#  'methylformamide': ['CNC=O'],
#  'ethyl-2-hydroxybenzoate': ['CCOC(=O)c1ccccc1O'],
#  'ethylbutyrate': ['CCCC(=O)OCC'],
#  'formicacid': ['O=CO'],
#  'butyricacid': ['CCCC(=O)O'],
#  'ethylisothiocyanate': ['CCN=C=S'],
#  'dibutylphthalate': ['CCCCOC(=O)c1ccccc1C(=O)OCCCC'],
#  'ethylsuccinate': ['CCC(CC(=O)[O-])C(=O)[O-]'],
#  'methylbenzoate': ['COC(=O)c1ccccc1'],
#  'n-methylcyclohexanamine': ['CNC1CCCCC1'],
#  'methylformate': ['COC=O'],
#  'dimethylsulfide': ['CSC'],
#  '1-hexanol': ['CCCCCCO'],
#  'anisole': ['COc1ccccc1'],
#  '1-ethynylcyclohexanol': ['C#CC1(O)CCCCC1'],
#  'n-heptane': ['CCCCCCC'],
#  '1-octanamine': ['CCCCCCCCN'],
#  'n-methyl-2-pyrrolidinone': ['CN1CCCC1=O'],
#  'ch2br2': ['BrCBr'],
#  'n-bucooh': [],
#  'dimethylphthalate': ['COC(=O)c1ccccc1C(=O)OC'],
#  'diethylsulfide': ['CCSCC'],
#  'methylthiobenzene': ['CSc1ccccc1'],
#  'tetramethylurea': ['CN(C)C(=O)N(C)C'],
#  'ethyleneoxide': ['C1CO1'],
#  '1-bromo-1,2,2,2-tetrafluoroethane': ['FC(Br)C(F)(F)F'],
#  'ch2cl2': [],
#  'n-decane': ['CCCCCCCCCC'],
#  'dimethylmalonate': ['CC(C)(C(=O)[O-])C(=O)[O-]'],
#  'ch3i': ['CI'],
#  'aceticacidcyclohexylester': [],
#  'cyanoaceticacidethylester': [],
#  'nitricacid': ['O=[N+]([O-])O'],
#  'valeraldehyde': ['CCCCC=O'],
#  '2-hydroxypropanoicacidethylester': [],
#  'n-hexylacetate': [],
#  'butylphenylether': ['CCCCOc1ccccc1'],
#  'cyclohexanecarboxylicacid': ['O=C(O)C1CCCCC1'],
#  'ethylacetoacetate': ['CCOC(=O)CC(C)=O'],
#  'valeronitrile': ['CCCCC#N'],
#  'methylbutyrate': ['CCCC(=O)OC'],
#  'glycol': ['OCCO'],
#  'dimethylsulfate': ['COS(=O)(=O)OC'],
#  'carvon': ['C=C(C)C1CC=C(C)C(=O)C1'],
#  'methylvalerate': ['CCCCC(=O)OC'],
#  'dimethyldisulfide': ['CSSC'],
#  'dodecanoicacidmethylester': [],
#  'n-hexanoicacid': ['CCCCCC(=O)O'],
#  'diethyleneglycol': ['OCCOCCO'],
#  'decanoicacidmethylester': [],
#  'ethyloxalat': ['CCOC(=O)C(=O)[O-]'],
#  'n,n-diethyl-benzeneamine': [],
#  'ethylacetate': ['CCOC(C)=O'],
#  'diethylmaleate': ['CC/C(C(=O)[O-])=C(\\CC)C(=O)[O-]'],
#  'diethyldisulfide': ['CCSSCC'],
#  '2,4-dimethyl-3-thiapentane': ['CC(C)SC(C)C'],
#  'dimethylformamide': ['CN(C)C=O'],
#  'n-butylacetate': [],
#  'ethylnitrate': ['CCO[N+](=O)[O-]'],
#  'methyltrichloroacetate': ['COC(=O)C(Cl)(Cl)Cl'],
#  'methylhexanoate': ['CCCCCC(=O)OC'],
#  'thp': [],
#  'decanedioicaciddibutylester': [],
#  '2-hydroxy-benzoicacidmethylester': [],
#  'methylacetate': ['COC(C)=O'],
#  'di-n-pentylether': ['CCCCCOCCCCC'],
#  'ethylbenzoate': ['CCOC(=O)c1ccccc1'],
#  'cs2': [],
#  'ethylhexanoate': ['CCCCCC(=O)OCC'],
#  'tri-n-butylamine': ['CCCCN(CCCC)CCCC'],
#  '1-(2-thienyl)ethanethiol': ['CC(S)c1cccs1'],
#  'propylene glycol dimethyl ether': ['COCC(C)OC'],
#  'propylene glycol phenyl ether': ['CC(O)COc1ccccc1'],
#  '1-undecanol': ['CCCCCCCCCCCO'],
#  'n-pentylacetate': ['CCCCCOC(C)=O'],
#  'tetralin': ['c1ccc2c(c1)CCCC2'],
#  'dipropylene glycol methyl ether acetate': ['COC(C)COC(C)COC(C)=O'],
#  'n-undecane': ['CCCCCCCCCCC'],
#  '2-[2-(hexyloxy)ethoxy]ethanol': ['CCCCCCOCCOCCO'],
#  'ethylene glycol diacetate': ['CC(=O)OCCOC(C)=O'],
#  '2-phenoxyethanol': ['OCCOc1ccccc1'],
#  '2-(2-ethoxyethoxy)ethanol': ['CCOCCOCCO'],
#  'perfluorooctane': ['FC(F)(F)C(F)(F)C(F)(F)C(F)(F)C(F)(F)C(F)(F)C(F)(F)C(F)(F)F'],
#  '1-methoxy-2-propanol': ['COCC(C)O'],
#  'n-propylbenzene': ['CCCc1ccccc1'],
#  'n-methylcaprolactam': ['CN1CCCCCC1=O'],
#  '1,1,3,3-tetramethylurea': ['CN(C)C(=O)N(C)C'],
#  '4-methyl-1,3-dioxolan-2-one': ['CC1COC(=O)O1'],
#  'tetrahydrothiophene-1,1-dioxide': ['O=S1(=O)CCCC1'],
#  '1-propoxy-2-propanol': ['CCCOCC(C)O'],
#  'ethylene glycol': ['OCCO'],
#  'phenylacetate': ['O=C([O-])Cc1ccccc1'],
#  '1-methoxy-2-propanol acetate': ['COCC(C)OC(C)=O'],
#  'biurea': ['NC(=O)NNC(N)=O'],
#  'n-propylamine': ['CCCN'],
#  '3-butoxypropan-2-ol': ['CCCCOCC(C)O'],
#  'pocl3': [],
#  "hunig's base": [],
#  'd4': [],
#  'mchm': [],
#  'tes': [],
#  'h2o': ['O'],
#  'pcl3': ['ClP(Cl)Cl'],
#  'propylpropionate': ['CCCOC(=O)CC'],
#  'propionicacid': ['CCC(=O)O'],
#  'tfa': ['O=C(O)C(F)(F)F'],
#  'propionitrile': ['CCC#N'],
#  'chinoline': ['c1ccc2ncccc2c1'],
#  'iso-butanol': ['CC(C)CO'],
#  'isoamyl acetate': ['CC(=O)OCCC(C)C'],
#  'propylene glycol diacetate': ['CC(=O)OCC(C)OC(C)=O'],
#  'perfluorotoluene': ['Fc1c(F)c(F)c(C(F)(F)F)c(F)c1F'],
#  'trimethylphosphate': ['COP(=O)(OC)OC'],
#  'dicyanomethane': ['N#CCC#N'],
#  'n-pentylamine': ['CCCCCN'],
#  'vinylacetate': ['C=CCC(=O)[O-]'],
#  'nnm': [],
#  'dipropylene glycol n-butyl ether': ['CCCCOC(C)COC(C)CO'],
#  'propan-2-ol': ['CC(C)O'],
#  'ethylene glycol monobutyl ether': ['CCCCOCCO'],
#  '2-picoline': ['Cc1ccccn1'],
#  'triethyl orthoformate': ['CCOC(OCC)OCC'],
#  'triethylphosphate': ['CCOP(=O)(OCC)OCC'],
#  'thionylchloride': ['O=S(Cl)Cl'],
#  'd-limonene': ['C=C(C)C1CC=C(C)CC1'],
#  'tfaa': ['O=C(OC(=O)C(F)(F)F)C(F)(F)F'],
#  'dbu': ['C1CCC2=NCCCN2CC1'],
#  'glycerol-triacetate': ['CC(=O)OCC(COC(C)=O)OC(C)=O'],
#  'thf': ['C1CCOC1'],
#  'phenylisothiocyanat': ['S=C=Nc1ccccc1'],
#  '2-[2-(methoxy)ethoxy]ethanol': ['COCCOCCO'],
#  'formicacidpentylester': [],
#  '2-[2-(butyloxy)ethoxy]ethanol': ['CCCCOCCOCCO'],
#  'tripropylene glycol methyl ether': ['COC(C)COC(C)COC(C)CO'],
#  'phenyl-hydrazine': ['NNc1ccccc1'],
#  'tert-amyl alcohol': ['CCC(C)(C)O'],
#  'butyrolactone': ['O=C1CCCO1'],
#  'perfluoromethylcyclohexane': ['FC(F)(F)C1(F)C(F)(F)C(F)(F)C(F)(F)C(F)(F)C1(F)F'],
#  '2-propoxyethanol': ['CCCOCCO'],
#  'trifluoroaceticacid': ['O=C(O)C(F)(F)F'],
#  '1-(1-propoxypropan-2-yloxy)propan-2-ol': ['CCCOCC(C)OCC(C)O'],
#  '1-ethylpyrrolidin-2-one': ['CCN1CCCC1=O'],
#  'isocyanatobenzene': ['O=C=Nc1ccccc1'],
#  'nmp': ['CN1CCCC1=O'],
#  'm2': [],
#  'ccl4': ['ClC(Cl)(Cl)Cl'],
#  'cfcl3': ['FC(Cl)(Cl)Cl'],
#  'chbr3': [],
#  'n-propylacetate': [],
#  'dicyclopentadiene': [],
#  'd5': [],
#  'trichloroacetonitrile': ['N#CC(Cl)(Cl)Cl'],
#  'chcl3': [],
#  'tert-butylmethylether': ['COC(C)(C)C'],
#  'n-propylformate': [],
#  'mdm': [],
#  '3,6,9-trioxatridecan-1-ol': ['CCCCOCCOCCOCCO'],
#  'tripropylene glycol n-butyl ether': ['CCCCOC(C)COC(C)COC(C)CO'],
#  'isophorone': ['CC1=CC(=O)CC(C)(C)C1'],
#  'triethyleneglycol dimethyl ether': ['COCCOCCOCCOC'],
#  'tetrahydro-2h-thiopyran': ['C1CCSCC1'],
#  'dipropylene glycol methyl ether': ['COC(C)COC(C)CO'],
#  '2-(2-butoxyethoxy)ethyl acetate': ['CCCCOCCOCCOC(C)=O'],
#  'md2m': [],
#  'trifluoromethylphenyl ether': ['FC(F)(F)Oc1ccccc1'],
#  'tetranitro-methane': ['O=[N+]([O-])C([N+](=O)[O-])([N+](=O)[O-])[N+](=O)[O-]'],
#  'propylnitrate': ['CCCO[N+](=O)[O-]'],
#  'sulfurylchloride': ['O=S(=O)(Cl)Cl'],
#  'methylbutylketone': ['CCCCC(C)=O'],
#  'tetrahydropyran': ['C1CCOCC1'],
#  '5-methyldihydrofuran-2(3h)-one': ['CC1CCC(=O)O1'],
#  'trimethyl orthoformate': ['COC(OC)OC'],
#  'thfa': ['OCC1CCCO1'],
#  'tame': [],
#  'etbe': ['CCOC(C)(C)C'],
#  'isopropyl alcohol': ['CC(C)O'],
#  'dihydrolevoglucosenone': [],
#  'cpme': ['COC1CCCC1'],
#  'diispropylethylamine': [],
#  'tmthf': [],
#  'mbk': [],
#  'gvl': [],
#  'butyl ether': ['CCCCOCCCC'],
#  'tert-butylbenzene': ['CC(C)(C)c1ccccc1']}

# %%
solvents_df.columns
# Out:
# Index(['solvent_name_1', 'solvent_name_2', 'solvent_name_3', 'cas_number',
#        'chemical_formula', 'smiles', 'source'],
#       dtype='object')

# %%
cas_names = apply_pura_cas_to_smiles(solvents_df['cas_number'].dropna().tolist())
# Out:
# Batch 0 Progress: 100%|██████████| 100/100 [00:03<00:00, 26.30it/s]
# Batch 1 Progress: 100%|██████████| 100/100 [00:00<00:00, 132.21it/s]
# Batch:  40%|████      | 2/5 [00:04<00:06,  2.02s/it]ERROR:pura.resolvers:<pura.services.cas.CAS object at 0x14835a7d0>, identifier_type=<CompoundIdentifierType.CAS_NUMBER: 7> value='2244-16-8  ' details=None: Not Found
# Batch 2 Progress: 100%|██████████| 100/100 [00:00<00:00, 163.64it/s]
# Batch 3 Progress: 100%|██████████| 100/100 [00:00<00:00, 158.27it/s]
# Batch:  80%|████████  | 4/5 [00:05<00:01,  1.09s/it]ERROR:pura.resolvers:<pura.services.cas.CAS object at 0x14835a7d0>, identifier_type=<CompoundIdentifierType.CAS_NUMBER: 7> value='"7719-09-7"' details=None: Not Found
# ERROR:pura.resolvers:<pura.services.cas.CAS object at 0x14835a7d0>, identifier_type=<CompoundIdentifierType.CAS_NUMBER: 7> value='"7719-12-2"' details=None: Not Found
# ERROR:pura.resolvers:<pura.services.cas.CAS object at 0x14835a7d0>, identifier_type=<CompoundIdentifierType.CAS_NUMBER: 7> value='71-41-0 ' details=None: Not Found
# Batch 4 Progress: 100%|██████████| 85/85 [00:00<00:00, 135.46it/s]
# Batch: 100%|██████████| 5/5 [00:06<00:00,  1.30s/it]

# %%
cas_names_dict = dict(cas_names)

# %%
cas_names_dict_2 ={key: value[0] if value else '' for key, value in cas_names_dict.items()}

# %%
names_dict_2 = {key: value[0] if value else '' for key, value in names_dict.items()}

# %%
replacement_df = solvents_df.replace(names_dict_2)

# %%
replacement_df_2 = replacement_df.replace(cas_names_dict_2)

# %%
replacement_df_2.to_csv('orderly/data/pura_solvents_.csv', index=False)

# %% [markdown]
# # Resolve pura smiles

# %%
pura_solvents = pd.read_csv('orderly/data/pura_solvents.csv')

# %%
pura_solvents
# Out:
#              smiles_1         smiles_2 smiles_3           smiles_4  \
# 0    C1=C\CC/C=C\CC/1     C1=CCCC=CCC1      NaN       C1=CCCC=CCC1
# 1         C/C=C/C=C/C      C/C=C/C=C/C      NaN           CC=CC=CC
# 2     ClC(Cl)c1ccccc1  ClC(Cl)c1ccccc1      NaN    ClC(Cl)c1ccccc1
# 3           C=C/C=C/C              NaN      NaN            C=CC=CC
# 4           C/C=C/C#N              NaN      NaN            CC=CC#N
# ..                ...              ...      ...                ...
# 610   CC(=O)OC(C)(C)C              NaN      NaN    CC(=O)OC(C)(C)C
# 611      CCOC(C)(C)CC              NaN      NaN        CCC(C)(C)OC
# 612         OCC1CCCO1        OCC1CCCO1      NaN          OCC1CCCO1
# 613   CC1(C)CCOC1(C)C              NaN      NaN  CC1(C)CCC(C)(C)O1
# 614               NaN              NaN      NaN                NaN
#
#               smiles_5
# 0     C\1C\C=C/CC\C=C1
# 1          C/C=C/C=C/C
# 2      ClC(Cl)c1ccccc1
# 3            C/C=C/C=C
# 4            C/C=C/C#N
# ..                 ...
# 610    O=C(OC(C)(C)C)C
# 611      O(C(C)(C)CC)C
# 612        C1CC(OC1)CO
# 613  CC1(CCC(O1)(C)C)C
# 614       Cc1c(C)cccc1
#
# [615 rows x 5 columns]

# %%
# Canonicalise and remove stoichiometry
def clean_smiles(smiles):
    if pd.isna(smiles):
        return smiles
    else:
        mol = Chem.MolFromSmiles(smiles)
        return Chem.MolToSmiles(mol, isomericSmiles=False)

# Apply the function to all columns in the DataFrame
df = pura_solvents.applymap(clean_smiles)
# Out:
# [19:48:12] WARNING: not removing hydrogen atom without neighbors
# [19:48:12] WARNING: not removing hydrogen atom without neighbors
# [19:48:12] WARNING: not removing hydrogen atom without neighbors

# %%
df = df.drop('smiles_5', axis=1)

# %%
df = df.drop('final_smiles', axis=1)

# %%
df
# Out:
#             smiles_1         smiles_2 smiles_3           smiles_4
# 0       C1=CCCC=CCC1     C1=CCCC=CCC1      NaN       C1=CCCC=CCC1
# 1           CC=CC=CC         CC=CC=CC      NaN           CC=CC=CC
# 2    ClC(Cl)c1ccccc1  ClC(Cl)c1ccccc1      NaN    ClC(Cl)c1ccccc1
# 3            C=CC=CC              NaN      NaN            C=CC=CC
# 4            CC=CC#N              NaN      NaN            CC=CC#N
# ..               ...              ...      ...                ...
# 610  CC(=O)OC(C)(C)C              NaN      NaN    CC(=O)OC(C)(C)C
# 611     CCOC(C)(C)CC              NaN      NaN        CCC(C)(C)OC
# 612        OCC1CCCO1        OCC1CCCO1      NaN          OCC1CCCO1
# 613  CC1(C)CCOC1(C)C              NaN      NaN  CC1(C)CCC(C)(C)O1
# 614              NaN              NaN      NaN                NaN
#
# [615 rows x 4 columns]

# %%
def get_final_smiles(row):
    row_dropna = row.dropna()
    smiles_set = set(row_dropna)
    if len(smiles_set) == 1 and len(row_dropna) >= 1:
        return smiles_set.pop()
    else:
        return np.nan

# Apply the function to each row in the DataFrame to generate the 'final_smiles' column
df['final_smiles'] = df.apply(get_final_smiles, axis=1)

# %%
df['final_smiles'].dropna()
# Out:
# 0            C1=CCCC=CCC1
# 1                CC=CC=CC
# 2         ClC(Cl)c1ccccc1
# 3                 C=CC=CC
# 4                 CC=CC#N
#               ...
# 606                    CO
# 608      Cc1ccc(C(C)C)cc1
# 609    C=C(C)C1CC=C(C)CC1
# 610       CC(=O)OC(C)(C)C
# 612             OCC1CCCO1
# Name: final_smiles, Length: 590, dtype: object

# %%
# need to manually reosolve 22 compounds where there's disagreement
df.to_csv('orderly/data/solvents_check_agreement.csv', index=False)
