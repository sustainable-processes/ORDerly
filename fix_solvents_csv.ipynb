# %% [markdown]
# # Fixing solvents csv

# %%
import pandas as pd

# %%
solvents_csv = pd.read_csv('orderly/data/solvents.csv')

# %%
solvents_csv
# Out:
#                                     solvent_name_1             solvent_name_2  \
# 0                         (trichloromethyl)benzene  (trichloromethyl)-benzene
# 1                      (1Z,5Z)-cycloocta-1,5-diene         1,5-cyclooctadiene
# 2                            (2E,4E)-2,4-hexadiene  trans,trans-2,4-hexadiene
# 3                          (dichloromethyl)benzene   (dichloromethyl)-benzene
# 4                               (E)-1,3-pentadiene       1-trans-3-pentadiene
# ..                                             ...                        ...
# 753  2,2,4-Trimethyl-1,3-pentanediol 1-isobutyrate                        NaN
# 754                            n-Pentyl Propionate                        NaN
# 755                                Butoxytriglycol  3,6,9-Trioxatridecan-1-ol
# 756              Dipropylene Glycol Dimethyl Ether                        NaN
# 757                                     Triacetin     1,2,3-triacetoxypropane
#
# ...

# %% [markdown]
# # Check for duplicates in the four name columns
